# %%
import os
import time
import cv2
import uuid
import numpy as np
import mediapipe as mp
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.2.0'

# %% [markdown]
# ## MediaPipe Hands
#
# Solução para detecção de 21 pontos chaves da mão. Fonte: https://google.github.io/mediapipe/solutions/hands.html

# %%
mp_drawing = mp.solutions.drawing_utils
# mp_drawing_styles = mp.solutions.drawing_styles
mp_hands = mp.solutions.hands  # Solução para detecção e rastreio de mão e dedos

# %%
# --- Variáveis globais ---
path = os.getcwd()
input_images_path = path + '\\images\\'
output_images_path = path + '\\output_images\\'

# %% [markdown]
# ![img_landmark_hand.PNG](attachment:img_landmark_hand.PNG)

# %% [markdown]
# As duas saídas (outputs) desse modelo são:
#
# ### I. Multi_handedness
#
# Coleção das mãos detectadas (ou seja, é uma mão esquerda ou direita). Cada mão é composta por um __label__ e um __score__. O label é uma string com o valor "Esquerda" ou "Direita". O score é a probabilidade estimada da mão prevista e é sempre maior ou igual a 0.5 (e a mão oposta tem uma probabilidade estimada de 1-score).
#
# **Observação:** Note-se que a mão é determinada assumindo que a imagem de entrada é espelhada, ou seja, tirada com uma câmara virada para a frente com as imagens viradas na horizontal. Se não for este o caso, por favor trocar a saída da mão na aplicação.
#
# ---
#
# ### II. Multi_hand_landmarks
#
# Conjunto de mãos detectadas, onde cada mão é representada como uma __lista de 21 marcos (pontos) de mão__ e cada marco de referência (ponto de referência) é composto por __x, y e z__. Desses, x e y são normalizados para [0.0, 1.0] pela largura e altura da imagem, respectivamente. Já z representa a profundidade do marco de referência, sendo a profundidade no pulso a origem (referência). Quanto menor o valor de z, mais próximo o marco de referência está da câmera. A magnitude de z usa aproximadamente a mesma escala que x.

# %% [markdown]
# ## 1. Testes iniciais

# %% [markdown]
# ### a. Vídeo

# %% [markdown]
# O bloco abaixo aciona a câmera webcam do notebook e aplica a detecção e rastreio das mãos e dedos na imagem. No pulso da mão detectada, aparece o label identifica ("left" ou  "right"), a precisão da identificação ("score") e as coordenadas desse ponto do pulso ("coords").
#
# **Observação**: na imagem, o referencial (0,0) é o ponto no campo superior esquerda da imagem.

# %%
def display_webcam(filename=None):
    """
    Inicializa webcam. Para parar o processo pressionar o botão 'q' e para salvar o frame (imagem) na pasta "images"
    pressione "s".
    """
    
    # Create a video capture object for the camera
    cap = cv2.VideoCapture(0)
    
    while(True):
        # Capture the video frame-by-frame
        _, frame = cap.read()

        # Display the resulting frame
        cv2.imshow('Frame', frame)
        
        # Press 'q' button to quit and 's' button to save the image
        if cv2.waitKey(1) & 0xFF == ord('q'):
            print("Terminando processo.")
            break
        elif cv2.waitKey(1) & 0xFF == ord('s'):
            if filename is None:
                print("Não foi passado nome de arquivo")
            else:
                try:
                    print("Salvar imagem")
                    cv2.imwrite(input_images_path + '\\' + filename, frame)
                    print("Imagem salva")
                except:
                    print("Não foi possivel salvar imagem. Terminando processo.")

    # Release the capture
    cap.release()
    cv2.destroyAllWindows()

# %%
# display_webcam("letra_a_afast.jpg")

# %%
def get_informations_hand(index, hand, mark_name, results):
    """
    Retorna um texto com o label (left ou right) e o score para uma mão específica (índice), e
    as coordenadas x e y desta mão para um ponto da mão específico.
    """
    output = None 
    
    # Loop sobre cada mão detectada
    for i, c in enumerate(results.multi_handedness):
        
        # Encontra a mão correta pelo índice
        if c.classification[0].index == index:
            
            # Extrair informações (label e score)
            label = c.classification[0].label
            score = c.classification[0].score
            text = 'Label: {}, Score: {}'.format(label, round(score, 2))
            # print(text)
            
            # Extrair coordenadas de um ponto específico
            # x = results.multi_hand_landmarks[i].landmark[mark_name].x
            # y = results.multi_hand_landmarks[i].landmark[mark_name].y
            # print(x, y)
            
            x = hand.landmark[mark_name].x
            y = hand.landmark[mark_name].y
            # print(x, y)
            
            # Cálculo de coordenadas
            multiply = np.multiply(np.array((x, y)),[640,480])  # TODO: colocar parâmetros da câmera ?
            coords = tuple(multiply.astype(int))
            # print(coords)
            
            output = text, coords
    
    return output

# %%
# t, c = get_informations_hand(0, hand, mp_hands.HandLandmark.WRIST, results)

# %%
cap = cv2.VideoCapture(0)  # Maioria dos casos a câmera do webcam é 0

# Comando 'with' garante que os recursos sejam fechados após a execução do bloco
with mp_hands.Hands(
    min_detection_confidence=0.8,  # Nivel de confiança mínimo para detecção
    min_tracking_confidence=0.5,  # Nível de confiança mínimo para rastreio
    ) as hands:
    
    # Enquanto a câmera está aberta
    while cap.isOpened():
        # Leitura da imagem da câmera
        _, frame = cap.read()  # Frame é lido em formato BGR
        
        # Converte BGR para RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Inverte na horizontal
        image = cv2.flip(image, 1)
        
        # Para aumentar performance flag a imagem, será passada então como referência
        image.flags.writeable = False
        
        # Detecção
        results = hands.process(image)  # Imagem processada em RGB
        # print(results )
        
        # Flag como true
        image.flags.writeable = True
        
        # Converte RGB para BGR
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Mostrando resultados
        if results.multi_hand_landmarks:  # Caso haja algum resultado
            
            # Iteração em cada mão
            for num, hand in enumerate(results.multi_hand_landmarks):
                
                # Desenhar as conexões em cada imagem (frame) da câmera
                mp_drawing.draw_landmarks(image, hand, mp_hands.HAND_CONNECTIONS, 
                                        mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
                                        mp_drawing.DrawingSpec(color=(250, 44, 250), thickness=2, circle_radius=2)
                                        )
                
                # Mostra o label da mão
                if get_informations_hand(num, hand, mp_hands.HandLandmark.WRIST, results):
                    text, coord = get_informations_hand(num, hand, mp_hands.HandLandmark.WRIST, results)
                    
                    # Mostrar na imagem o label e o score
                    cv2.putText(image,  # imagem
                                text,  # texto
                                coord,  # coordenada onde vai ser colocado o texto
                                cv2.FONT_HERSHEY_SIMPLEX,  # fonte
                                0.5,  # escala
                                (255, 255, 255),  # cor
                                1,  # Espessura
                                cv2.LINE_AA)
                    
                    # Mostrar na imagem as coordenadas de um ponto
                    x_ = coord[0]
                    y_ = coord[1] + 30
                    coord_ = tuple((x_, y_))
                    cv2.putText(image,  # imagem
                                str(coord),  # texto
                                coord_,  # coordenada onde vai ser colocado o texto
                                cv2.FONT_HERSHEY_SIMPLEX,  # fonte
                                0.4,  # escala
                                (255, 255, 255),  # cor
                                1,  # Espessura
                                cv2.LINE_AA)
        
        # Mostrar imagem
        cv2.imshow('Hand tracking', image)
        
        # Sair do loop
        if cv2.waitKey(5) & 0xFF == ord('q'):  # Pressionar 'q' para sair
            # Salvar imagem com nome único
            file_name = '{}.jpg'.format(uuid.uuid1())  # Nome único
            cv2.imwrite(output_images_path + file_name, image)  # Salvar frame
            break
            
# Libera recursos alocados
cap.release()
cv2.destroyAllWindows()

# %%
# Libera recursos alocados
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# **Exemplos:**<br>
# Imagem abaixo mostra um exemplo do funcionamento do bloco acima

# %%
# Usando matplotlib
img_path = output_images_path + "example_img.jpg"
img = plt.imread(img_path)
plt.imshow(img)
plt.title("Exemplo de aplicação de solução para detecção e rastreio de mãos e dedos")
plt.show()

# %%
# Usando opencv
img_path = output_images_path + "example_img.jpg"
# img = cv2.imread(img_path, 0)  # Grayscale
img = cv2.imread(img_path, cv2.IMREAD_COLOR)
cv2.imshow('Exemplo de deteccao e rastreio de maos e dedos', img)
cv2.waitKey(0)  # Clica botão teclado
cv2.destroyAllWindows()

# %%
# Usando opencv para ler e matplotlib para mostrar imagem
img_path = output_images_path + "example_img.jpg"
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title("Exemplo de aplicação de solução para detecção e rastreio de mãos e dedos")
plt.show()

# %%
# Use '??' após alguma função para obter mais detalhes
mp_drawing.DrawingSpec??

# %%
# Comando para ler docstring ('??')
cv2.putText??

# %% [markdown]
# ### b. Imagem

# %% [markdown]
# Por sua vez, o bloco abaixo lerá uma imagem e aplicará o processo de identificação e detecção de mãos e dedos. Assim como feito na aplicação com a imagem acima, a mão identificada terá um "label" ("left" ou "rigth"), "score" e as coordenadas do ponto 0 (pulso).

# %%
img = plt.imread(input_images_path + "letra_a_prox.jpg")
print("Type: " + str(type(img)))
print("Shape: " + str(img.shape))
plt.imshow(img)
plt.title("Letra A - antes de processar imagem")
plt.show()
# Out:
# Type: <class 'numpy.ndarray'>
# Shape: (480, 640, 3)

# %%
# Arquivo a ser lido
file = input_images_path + "letra_a_img.jpg"
file = input_images_path + "image_a_prox.jpg"

# Comando 'with' garante que os recursos sejam fechados após a execução do bloco
with mp_hands.Hands(
    static_image_mode=True,  # Modo para entrada imagem
    max_num_hands=2,  # Número máximo de mãos na imagem
    min_detection_confidence=0.8,  # Nivel de confiança mínimo para detecção
    min_tracking_confidence=0.5,  # Nível de confiança mínimo para rastreio
    ) as hands:

    # Ler imagem, invertê-la na horizontal
    img = cv2.flip(cv2.imread(file), 1)  # Imagem lida com formato BGR
    
    # Converte imagem antes de processa-la
    results = hands.process(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Imagem processa em formato RBG

    # Print handedness e desenha os contorno e linhas da mão
    print('Handedness:', results.multi_handedness)
    
    # if not results.multi_hand_landmarks:
    #    continue
    
    # Dimensões da imagem
    image_height, image_width, _ = img.shape
    
    # Faz uma cópia
    annotated_image = img.copy()
    
    # Mostrando resultados
    for num, hand_landmarks in enumerate(results.multi_hand_landmarks):  # Iteração em cada mão identificada
        
        # print('hand_landmarks:', hand_landmarks)
        print(
          f'Index finger tip coordinates: (',
          f'{hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].x * image_width}, '
          f'{hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].y * image_height})'
        )
        
        # Desenhar as conexões na imagem cópia
        mp_drawing.draw_landmarks(annotated_image,
                                  hand_landmarks,
                                  mp_hands.HAND_CONNECTIONS
                                  # mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
                                  # mp_drawing.DrawingSpec(color=(250, 44, 250), thickness=2, circle_radius=2)
                                  )
        
        # Mostra o label da mão
        if get_informations_hand(num, hand_landmarks, mp_hands.HandLandmark.WRIST, results):  # TODO: não está funcionando!
            text, coord = get_informations_hand(num, hand_landmarks, mp_hands.HandLandmark.WRIST, results)
            print(text, coord)
                    
            # Mostrar na imagem o label e o score
            cv2.putText(annotated_image,  # imagem
                        text,  # texto
                        coord,  # coordenada onde vai ser colocado o texto
                        cv2.FONT_HERSHEY_SIMPLEX,  # fonte
                        0.5,  # escala
                        (255, 255, 255),  # cor
                        1,  # Espessura
                        cv2.LINE_AA)
            
            # Mostrar na imagem as coordenadas de um ponto
            x_ = coord[0]
            y_ = coord[1] + 30
            coord_ = tuple((x_, y_))
            cv2.putText(annotated_image,  # imagem
                        str(coord),  # texto
                        coord_,  # coordenada onde vai ser colocado o texto
                        cv2.FONT_HERSHEY_SIMPLEX,  # fonte
                        0.4,  # escala
                        (255, 255, 255),  # cor
                        1,  # Espessura
                        cv2.LINE_AA)
        
        # mp_drawing.draw_landmarks(
        #      annotated_image,
        #      hand_landmarks,
        #      mp_hands.HAND_CONNECTIONS,
        #      mp_drawing_styles.get_default_hand_landmarks_style(),
        #      mp_drawing_styles.get_default_hand_connections_style()
        # )
        # cv2.imwrite(
        #    '/tmp/annotated_image' + str(idx) + '.png', cv2.flip(annotated_image, 1))

    # Mostrar imagem com desenhos
    annotated_image = cv2.flip(annotated_image, 1)
    annotated_image = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)
    
    plt.imshow(annotated_image)
    plt.title("Letra A - depois de processar a imagem")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-64-6db1daf86c09> in <module>
#      15
#      16     # Converte imagem antes de processa-la
# ---> 17     results = hands.process(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Imagem processa em formato RBG
#      18
#      19     # Print handedness e desenha os contorno e linhas da mão
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %% [markdown]
# ## 2. Extrair informações dos dedos

# %% [markdown]
# Os dedos são descritos por quatro pontos. Segue abaixo os pontos para cada dedo da mão:
# - **indicador**: pontos [8,7,6,5]
# - **polegar**: pontos [4,3,2,1]
# - **médio**: pontos [12,11,10,9]
# - **anelar**: pontos [16,15,14,13]
# - **mínimo**: pontos [20,19,18,17]

# %% [markdown]
# ![img_landmark_hand.PNG](attachment:img_landmark_hand.PNG)

# %%
HAND_FINGERS = ["thumb", "index-finger", "middle-finger", "ring-finger", "pinky"]
img_height = image_height
img_width = image_width

# %%
hand_fingers_points = extrair_pontos_dedos(None, img_height, img_width)
for f in hand_fingers_points.keys():
    print(f)
    print(f"x:{hand_fingers_points[f]['x']}")
    print(f"y:{hand_fingers_points[f]['y']}")
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-1aeec91cfce7> in <module>
# ----> 1 hand_fingers_points = extrair_pontos_dedos(None, img_height, img_width)
#       2 for f in hand_fingers_points.keys():
#       3     print(f)
#       4     print(f"x:{hand_fingers_points[f]['x']}")
#       5     print(f"y:{hand_fingers_points[f]['y']}")
#
# <ipython-input-17-eecdd558229c> in extrair_pontos_dedos(hand, img_height, img_width)
#      25
#      26         for i in range(init, init+len_finger):
# ---> 27             points_x.append(hand.landmark[i].x * img_width)
#      28             points_y.append(hand.landmark[i].y * img_height)
#      29
#
# AttributeError: 'NoneType' object has no attribute 'landmark'

# %%
# Libera recursos alocados
cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)  # Maioria dos casos a câmera do webcam é 0

# Comando 'with' garante que os recursos sejam fechados após a execução do bloco
with mp_hands.Hands(
    min_detection_confidence=0.8,  # Nivel de confiança mínimo para detecção
    min_tracking_confidence=0.5,  # Nível de confiança mínimo para rastreio
    ) as hands:
    
    # Enquanto a câmera está aberta
    while cap.isOpened():
        # Leitura da imagem da câmera
        _, frame = cap.read()  # Frame é lido em formato BGR
        height, width, _ = frame.shape
        # print(f"Altura: {height}, largura: {width}")
        
        # Converte BGR para RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Inverte na horizontal
        image = cv2.flip(image, 1)
        
        # Para aumentar performance flag a imagem, será passada então como referência
        image.flags.writeable = False
        
        # Detecção
        results = hands.process(image)  # Imagem processada em RGB
        # print(results )
        
        # Flag como true
        image.flags.writeable = True
        
        # Converte RGB para BGR
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Mostrando resultados
        if results.multi_hand_landmarks:  # Caso haja algum resultado
            
            # Iteração em cada mão
            for num, hand in enumerate(results.multi_hand_landmarks):
                
                # Desenhar as conexões em cada imagem (frame) da câmera
                mp_drawing.draw_landmarks(image, hand, mp_hands.HAND_CONNECTIONS, 
                                        mp_drawing.DrawingSpec(color=(121, 22, 76), thickness=2, circle_radius=4),
                                        mp_drawing.DrawingSpec(color=(250, 44, 250), thickness=2, circle_radius=2)
                                        )
                
                # --- Testar funções de extrações ---
                # 1. Direção da mão
                hand_direction = verificar_direcao_mao(hand)  # up ou down
                print(hand_direction)
                finger = "index-finger"
                finger = "thumb"
                # 2. Condição dos dedos (esticado ou dobrado)
                estado = verificar_condicao_dedos(finger, hand, hand_direction, image_height)
                # print(estado)
                # 3. Condição dos dedos (proximidade entre os dedos)
                # estado = verificar_distancia_dedos_adjacentesi([])
                # print("Verificar proximidade entre os dedos (próximo ou afastado)")
                hand_fingers_points = extrair_pontos_dedos(hand, height, width)
                estados = verificar_distancia_dedos_adjacentes(states, hand, hand_fingers_points)
                # print(f"Estado dos dedos:\n{estados}")
                identified_letter = encontrar_letra(AlphabetLetters, estados)
                # print(f"Letra indentificada: {letter}\n")
                
                letter_text = "Letra identificada: "
                if identified_letter != "Not found":
                    letter_text = letter_text + identified_letter
                
                # Mostrar na imagem a letra identificada
                coord_ = tuple((50, 50))
                cv2.putText(image,  # imagem
                            letter_text,  # texto
                            coord_,  # coordenada onde vai ser colocado o texto
                            cv2.FONT_HERSHEY_SIMPLEX,  # fonte
                            0.5,  # escala
                            (255, 0, 0),  # cor: BGR
                            1,  # Espessura
                            cv2.LINE_AA)
                
                
                # Mostra o label da mão
                if get_informations_hand(num, hand, mp_hands.HandLandmark.WRIST, results):
                    text, coord = get_informations_hand(num, hand, mp_hands.HandLandmark.WRIST, results)
                    
                    # Mostrar na imagem o label e o score
                    cv2.putText(image,  # imagem
                                text,  # texto
                                coord,  # coordenada onde vai ser colocado o texto
                                cv2.FONT_HERSHEY_SIMPLEX,  # fonte
                                0.5,  # escala
                                (255, 255, 255),  # cor
                                1,  # Espessura
                                cv2.LINE_AA)
                    
                    # Mostrar na imagem as coordenadas de um ponto
                    x_ = coord[0]
                    y_ = coord[1] + 30
                    coord_ = tuple((x_, y_))
                    cv2.putText(image,  # imagem
                                str(coord),  # texto
                                coord_,  # coordenada onde vai ser colocado o texto
                                cv2.FONT_HERSHEY_SIMPLEX,  # fonte
                                0.4,  # escala
                                (255, 255, 255),  # cor
                                1,  # Espessura
                                cv2.LINE_AA)
        
        # Mostrar imagem
        cv2.imshow('Hand tracking', image)
        
        # Sair do loop
        if cv2.waitKey(5) & 0xFF == ord('q'):  # Pressionar 'q' para sair
            # Salvar imagem com nome único
            file_name = '{}.jpg'.format(uuid.uuid1())  # Nome único
            # cv2.imwrite(output_images_path + file_name, image)  # Salvar frame
            break
            
# Libera recursos alocados
cap.release()
cv2.destroyAllWindows()
# Out:
# up
# 25.03948211669922
# Go: 0.29374739321816057
# 39.27825927734375
# Go: 0.4607877359081625
# 40.9906005859375
# Go: 0.48087584289675445
# 40.9906005859375
# Go: 0.48087584289675445
# up
# 22.71068572998047
# Go: 0.2640787835680823
# 46.04667663574219
# Go: 0.535428586256523
# 37.770233154296875
# Go: 0.4391904914303153
# 37.770233154296875
# Go: 0.4391904914303153
# up
# 22.28839874267578
# Go: 0.2615402227924289
# 47.958526611328125
# Go: 0.5627628920110372
# 39.91558074951172
# Go: 0.4683840235740142
# 39.91558074951172
# Go: 0.4683840235740142
# up
# 25.011062622070312
# Go: 0.2926148392743875
# 46.14875793457031
# Go: 0.5399135410512645
# 38.36387634277344
# Go: 0.44883496873408324
# 38.36387634277344
# Go: 0.44883496873408324
# up
# 25.88367462158203
# Go: 0.2981345418212208
# 46.353187561035156
# Go: 0.5339074353816641
# 36.442604064941406
# Go: 0.419754892785366
# 36.442604064941406
# Go: 0.419754892785366
# up
# 25.370407104492188
# Go: 0.2935856845029891
# 47.27928161621094
# Go: 0.5471146047809038
# 36.49742126464844
# Go: 0.4223472000446733
# 36.49742126464844
# Go: 0.4223472000446733
# up
# 27.523117065429688
# Go: 0.31369096395357343
# 45.53508758544922
# Go: 0.5189799354641869
# 35.712547302246094
# Go: 0.40702887546666294
# 35.712547302246094
# Go: 0.40702887546666294
# up
# 25.751953125
# Go: 0.29329033069519667
# 45.60619354248047
# Go: 0.5194113052667044
# 37.16533660888672
# Go: 0.42327794756028564
# 37.16533660888672
# Go: 0.42327794756028564
# up
# 27.336807250976562
# Go: 0.3037453926465452
# 45.18211364746094
# Go: 0.5020285918707127
# 32.35065460205078
# Go: 0.3594553743697208
# 32.35065460205078
# Go: 0.3594553743697208
# up
# 24.520950317382812
# Go: 0.28650383066196533
# 42.802886962890625
# Go: 0.5001107591481039
# 30.926742553710938
# Go: 0.361349380707049
# 30.926742553710938
# Go: 0.361349380707049
# up
# 25.280532836914062
# Go: 0.2831598337694189
# 36.05293273925781
# Go: 0.403818325634407
# 20.816802978515625
# Go: 0.23316290479448434
# 20.816802978515625
# Go: 0.23316290479448434
# up
# 21.31397247314453
# Go: 0.24428842301068027
# 35.81535339355469
# Go: 0.4104948625182716
# 17.340316772460938
# Go: 0.19874468000685996
# 17.340316772460938
# Go: 0.19874468000685996
# up
# 20.087966918945312
# Go: 0.23246935506015093
# 37.43431091308594
# Go: 0.43321109349692016
# 14.551734924316406
# Go: 0.16840093606843312
# 14.551734924316406
# Go: 0.16840093606843312
# up
# 21.538963317871094
# Go: 0.2492124264811844
# 36.274375915527344
# Go: 0.41970567977608303
# 16.181793212890625
# Go: 0.18722832161821173
# 16.181793212890625
# Go: 0.18722832161821173
# up
# 20.399436950683594
# Go: 0.2279880885423045
# 38.63788604736328
# Go: 0.43182455508697454
# 15.632209777832031
# Go: 0.174708627280069
# 15.632209777832031
# Go: 0.174708627280069
# up
# 21.13964080810547
# Go: 0.23426871638001498
# 39.112205505371094
# Go: 0.4334400126146612
# 17.079010009765625
# Go: 0.18926895628685925
# 17.079010009765625
# Go: 0.18926895628685925
# up
# 20.288009643554688
# Go: 0.22454271110040128
# 39.86083984375
# Go: 0.4411699916604682
# 14.27337646484375
# Go: 0.15797422735309424
# 14.27337646484375
# Go: 0.15797422735309424
# up
# 21.195907592773438
# Go: 0.23988030981125827
# 34.90875244140625
# Go: 0.39507260135555916
# 15.745162963867188
# Go: 0.178192632387628
# 15.745162963867188
# Go: 0.178192632387628
# up
# 23.019638061523438
# Go: 0.25785414532823475
# 32.60650634765625
# Go: 0.36524131282792816
# 14.976882934570312
# Go: 0.16776333921729242
# 14.976882934570312
# Go: 0.16776333921729242
# up
# 22.7197265625
# Go: 0.25139577790637746
# 35.495567321777344
# Go: 0.3927615825189977
# 13.034744262695312
# Go: 0.14423059470881247
# 13.034744262695312
# Go: 0.14423059470881247
# up
# 20.38257598876953
# Go: 0.2311291117601092
# 35.33123016357422
# Go: 0.4006400294839211
# 14.256591796875
# Go: 0.16166324612520674
# 14.256591796875
# Go: 0.16166324612520674
# up
# 21.494293212890625
# Go: 0.23748590156638022
# 38.16303253173828
# Go: 0.42165527833553346
# 13.983573913574219
# Go: 0.15450155188139275
# 13.983573913574219
# Go: 0.15450155188139275
# up
# 19.952850341796875
# Go: 0.22131961288150961
# 36.96918487548828
# Go: 0.4100670102280328
# 16.018829345703125
# Go: 0.1776829399747158
# 16.018829345703125
# Go: 0.1776829399747158
# up
# 21.104698181152344
# Go: 0.23292916273142658
# 36.08325958251953
# Go: 0.3982451381694237
# 16.321258544921875
# Go: 0.18013510806740268
# 16.321258544921875
# Go: 0.18013510806740268
# up
# 22.14923858642578
# Go: 0.2480065377169695
# 38.94824981689453
# Go: 0.43610621419480333
# 14.296531677246094
# Go: 0.16007924194774503
# 14.296531677246094
# Go: 0.16007924194774503
# up
# 22.128868103027344
# Go: 0.24067390935008148
# 34.35638427734375
# Go: 0.3736605630556764
# 16.97338104248047
# Go: 0.1846027529001124
# 16.97338104248047
# Go: 0.1846027529001124
# up
# 23.67633819580078
# Go: 0.26221768477273777
# 33.47663879394531
# Go: 0.37075694078734045
# 15.784797668457031
# Go: 0.1748181270684422
# 15.784797668457031
# Go: 0.1748181270684422
# up
# 20.891151428222656
# Go: 0.23197671290960284
# 35.054893493652344
# Go: 0.3892518319056351
# 15.499343872070312
# Go: 0.17210572888008394
# 15.499343872070312
# Go: 0.17210572888008394
# up
# 23.08361053466797
# Go: 0.24837381567985337
# 33.42937469482422
# Go: 0.3596916234691816
# 16.877822875976562
# Go: 0.18160110879445282
# 16.877822875976562
# Go: 0.18160110879445282
# up
# 21.812744140625
# Go: 0.24463337166639285
# 34.554290771484375
# Go: 0.38753183012978476
# 14.073905944824219
# Go: 0.15784107866491429
# 14.073905944824219
# Go: 0.15784107866491429
# up
# 20.7781982421875
# Go: 0.22542586178300802
# 33.91643524169922
# Go: 0.36796461145722076
# 15.985679626464844
# Go: 0.17343109176166618
# 15.985679626464844
# Go: 0.17343109176166618
# up
# 18.544540405273438
# Go: 0.20480445828248864
# 33.498878479003906
# Go: 0.3699590019503722
# 19.47254180908203
# Go: 0.215053233428103
# 19.47254180908203
# Go: 0.215053233428103
# up
# 21.808929443359375
# Go: 0.2397251564591492
# 27.713851928710938
# Go: 0.3046324445659057
# 18.002281188964844
# Go: 0.19788223378200978
# 18.002281188964844
# Go: 0.19788223378200978
# up
# 21.378135681152344
# Go: 0.23279984796134232
# 29.369163513183594
# Go: 0.31981913215420293
# 20.834617614746094
# Go: 0.22688114087150138
# 20.834617614746094
# Go: 0.22688114087150138
# up
# 26.050376892089844
# Go: 0.29769510201003424
# 24.82769012451172
# Go: 0.28372264151519155
# 21.4398193359375
# Go: 0.24500717324464752
# 21.4398193359375
# Go: 0.24500717324464752
# up
# 25.2813720703125
# Go: 0.2795527272784793
# 21.674423217773438
# Go: 0.23966832598582383
# 20.49793243408203
# Go: 0.22665909506733503
# 20.49793243408203
# Go: 0.22665909506733503
# up
# 24.49848175048828
# Go: 0.2901589448765641
# 22.467918395996094
# Go: 0.26610904143988573
# 20.615501403808594
# Go: 0.24416909571595
# 20.615501403808594
# Go: 0.24416909571595
# up
# 24.197540283203125
# Go: 0.26514108677608184
# 22.26165771484375
# Go: 0.24392893041480176
# 24.608497619628906
# Go: 0.26964409301238806
# 24.608497619628906
# Go: 0.26964409301238806
# up
# 24.674034118652344
# Go: 0.28667399068929467
# 21.263351440429688
# Go: 0.2470471501962029
# 18.974647521972656
# Go: 0.2204559619594032
# 18.974647521972656
# Go: 0.2204559619594032
# up
# 23.040504455566406
# Go: 0.26555405263702847
# 20.946273803710938
# Go: 0.24141693194900687
# 27.34027862548828
# Go: 0.3151112339239561
# 27.34027862548828
# Go: 0.3151112339239561
# up
# 25.183677673339844
# Go: 0.2925346772181655
# 22.934799194335938
# Go: 0.2664116085984169
# 20.684547424316406
# Go: 0.24027258777148108
# 20.684547424316406
# Go: 0.24027258777148108
# up
# 24.175033569335938
# Go: 0.2728126945588367
# 17.794265747070312
# Go: 0.2008064051795901
# 25.407562255859375
# Go: 0.2867216503055633
# 25.407562255859375
# Go: 0.2867216503055633
# up
# 22.68291473388672
# Go: 0.2629609200861605
# 24.245033264160156
# Go: 0.2810704148677404
# 19.88067626953125
# Go: 0.23047483028982158
# 19.88067626953125
# Go: 0.23047483028982158
# up
# 25.60649871826172
# Go: 0.3107452891472187
# 23.825340270996094
# Go: 0.2891302060855958
# 19.47418212890625
# Go: 0.23632713019983606
# 19.47418212890625
# Go: 0.23632713019983606
# up
# 23.49018096923828
# Go: 0.2667182967445222
# 24.326438903808594
# Go: 0.27621355317697693
# 25.14118194580078
# Go: 0.2854645196437395
# 25.14118194580078
# Go: 0.2854645196437395
# up
# 23.788223266601562
# Go: 0.2707173949755306
# 24.436874389648438
# Go: 0.2780992469243369
# 23.973426818847656
# Go: 0.2728250691234637
# 23.973426818847656
# Go: 0.2728250691234637
# up
# 24.07367706298828
# Go: 0.2741583123205332
# 21.55010223388672
# Go: 0.24541907924239448
# 21.485061645507812
# Go: 0.2446783773589373
# 21.485061645507812
# Go: 0.2446783773589373
# up
# 25.090789794921875
# Go: 0.3001784554391372
# 20.9759521484375
# Go: 0.2509498094220045
# 22.68817901611328
# Go: 0.2714343625469257
# 22.68817901611328
# Go: 0.2714343625469257
# up
# 23.268280029296875
# Go: 0.27410468923063375
# 23.33232879638672
# Go: 0.2748591956821919
# 20.409317016601562
# Go: 0.24042557039890092
# 20.409317016601562
# Go: 0.24042557039890092
# up
# 23.630905151367188
# Go: 0.27402109434263355
# 25.65204620361328
# Go: 0.29745799950600826
# 19.640884399414062
# Go: 0.2277533002866468
# 19.640884399414062
# Go: 0.2277533002866468
# up
# 21.526756286621094
# Go: 0.23810157462852075
# 29.350433349609375
# Go: 0.324637130811702
# 20.159873962402344
# Go: 0.2229828623898985
# 20.159873962402344
# Go: 0.2229828623898985
# up
# 26.605262756347656
# Go: 0.3132377147656357
# 25.11547088623047
# Go: 0.29569761357792645
# 19.764747619628906
# Go: 0.23270074172881425
# 19.764747619628906
# Go: 0.23270074172881425
# up
# 24.646835327148438
# Go: 0.2790642328419058
# 29.92431640625
# Go: 0.3388186065425696
# 15.886802673339844
# Go: 0.1798786067866043
# 15.886802673339844
# Go: 0.1798786067866043
# up
# 25.95184326171875
# Go: 0.2991571156186898
# 25.195693969726562
# Go: 0.2904406850018645
# 16.999778747558594
# Go: 0.19596314315666533
# 16.999778747558594
# Go: 0.19596314315666533
# up
# 21.990394592285156
# Go: 0.24579652823836334
# 24.348526000976562
# Go: 0.2721544233163141
# 24.098434448242188
# Go: 0.26935903757887875
# 24.098434448242188
# Go: 0.26935903757887875
# up
# 23.37169647216797
# Go: 0.261677884102548
# 29.288253784179688
# Go: 0.32792177873905365
# 19.069442749023438
# Go: 0.21350831059788491
# 19.069442749023438
# Go: 0.21350831059788491
# up
# 22.184066772460938
# Go: 0.2483498101424887
# 30.867385864257812
# Go: 0.3455592474369823
# 19.34783935546875
# Go: 0.21659834871047856
# 19.34783935546875
# Go: 0.21659834871047856
# up
# 23.54114532470703
# Go: 0.26382051037880244
# 31.77417755126953
# Go: 0.3560863170767133
# 18.961639404296875
# Go: 0.2124989806681238
# 18.961639404296875
# Go: 0.2124989806681238
# up
# 26.356239318847656
# Go: 0.29693728215097337
# 26.89453125
# Go: 0.3030018401900208
# 22.88196563720703
# Go: 0.25779507479754094
# 22.88196563720703
# Go: 0.25779507479754094
# up
# 27.5494384765625
# Go: 0.32088597857811324
# 23.280715942382812
# Go: 0.2711654295068856
# 22.500267028808594
# Go: 0.2620750404749805
# 22.500267028808594
# Go: 0.2620750404749805
# up
# 24.14806365966797
# Go: 0.27603750025345963
# 23.056640625
# Go: 0.26356139904489867
# 22.672958374023438
# Go: 0.25917551159057317
# 22.672958374023438
# Go: 0.25917551159057317
# up
# 26.269264221191406
# Go: 0.293596713545667
# 20.92975616455078
# Go: 0.23392005095701077
# 23.68793487548828
# Go: 0.26474665493359323
# 23.68793487548828
# Go: 0.26474665493359323
# up
# 26.094741821289062
# Go: 0.3020527690900814
# 24.31591033935547
# Go: 0.2814623766446461
# 16.367835998535156
# Go: 0.18946154827776077
# 16.367835998535156
# Go: 0.18946154827776077
# up
# 22.148475646972656
# Go: 0.25694640132914376
# 25.162391662597656
# Go: 0.2919111043844064
# 21.217613220214844
# Go: 0.246147384976945
# 21.217613220214844
# Go: 0.246147384976945
# up
# 23.31623077392578
# Go: 0.26307040431589357
# 22.328643798828125
# Go: 0.25192774119186123
# 25.63274383544922
# Go: 0.2892069627333677
# 25.63274383544922
# Go: 0.2892069627333677
# up
# 25.06855010986328
# Go: 0.28801334975756726
# 22.537841796875
# Go: 0.25893796345525777
# 21.457366943359375
# Go: 0.24652435435038128
# 21.457366943359375
# Go: 0.24652435435038128
# up
# 26.7236328125
# Go: 0.3003963331651348
# 23.038253784179688
# Go: 0.258969542346737
# 20.243072509765625
# Go: 0.22754933045948642
# 20.243072509765625
# Go: 0.22754933045948642
# up
# 26.44073486328125
# Go: 0.3077870622309997
# 27.849159240722656
# Go: 0.32418202264903323
# 14.494781494140625
# Go: 0.1687285257701859
# 14.494781494140625
# Go: 0.1687285257701859
# up
# 28.031234741210938
# Go: 0.31784089204730576
# 16.81629180908203
# Go: 0.19067676607439862
# 26.122589111328125
# Go: 0.29619911867539406
# 26.122589111328125
# Go: 0.29619911867539406
# up
# 25.707969665527344
# Go: 0.28847115827225456
# 22.74280548095703
# Go: 0.25519881674085043
# 23.46881866455078
# Go: 0.2633454680212529
# 23.46881866455078
# Go: 0.2633454680212529
# up
# 25.382537841796875
# Go: 0.289695477932689
# 23.090248107910156
# Go: 0.2635331621643655
# 18.516273498535156
# Go: 0.2113295657874529
# 18.516273498535156
# Go: 0.2113295657874529
# up
# 27.30121612548828
# Go: 0.3192555929448254
# 18.29509735107422
# Go: 0.2139396327970735
# 24.190635681152344
# Go: 0.2828810153584474
# 24.190635681152344
# Go: 0.2828810153584474
# up
# 24.364395141601562
# Go: 0.2806780239009929
# 18.032493591308594
# Go: 0.2077344681778591
# 18.38878631591797
# Go: 0.21183896317116624
# 18.38878631591797
# Go: 0.21183896317116624
# up
# 26.6839599609375
# Go: 0.29242326049652934
# 15.170173645019531
# Go: 0.166246375952787
# 24.72972869873047
# Go: 0.271007298311929
# 24.72972869873047
# Go: 0.271007298311929
# up
# 22.710952758789062
# Go: 0.24910128429499862
# 19.575538635253906
# Go: 0.21471101924251082
# 23.746337890625
# Go: 0.26045773282534335
# 23.746337890625
# Go: 0.26045773282534335
# up
# 25.40752410888672
# Go: 0.2812729991024972
# 22.64270782470703
# Go: 0.2506652088713098
# 23.277435302734375
# Go: 0.25769193452125494
# 23.277435302734375
# Go: 0.25769193452125494
# up
# 25.3741455078125
# Go: 0.28095954496894227
# 22.456283569335938
# Go: 0.24865102201733547
# 17.447738647460938
# Go: 0.19319305588510685
# 17.447738647460938
# Go: 0.19319305588510685
# up
# 26.914596557617188
# Go: 0.31020318077518483
# 21.379165649414062
# Go: 0.24640477788959836
# 22.0166015625
# Go: 0.25375152177841326
# 22.0166015625
# Go: 0.25375152177841326
# up
# 26.49242401123047
# Go: 0.28761776258135907
# 21.763076782226562
# Go: 0.2362731114501591
# 27.893714904785156
# Go: 0.3028310232236839
# 27.893714904785156
# Go: 0.3028310232236839
# up
# 26.77886962890625
# Go: 0.2966155442682618
# 16.859474182128906
# Go: 0.18674358477068864
# 24.789352416992188
# Go: 0.274578701831643
# 24.789352416992188
# Go: 0.274578701831643
# up
# 22.9949951171875
# Go: 0.2583773320611636
# 18.7744140625
# Go: 0.21095386155809934
# 28.75946044921875
# Go: 0.32314826006784336
# 28.75946044921875
# Go: 0.32314826006784336
# up
# 26.430625915527344
# Go: 0.3108555579558529
# 20.971298217773438
# Go: 0.24664737904351963
# 17.919578552246094
# Go: 0.21075553061040908
# 17.919578552246094
# Go: 0.21075553061040908
# up
# 22.968521118164062
# Go: 0.25830630871800847
# 18.360977172851562
# Go: 0.20648940406634259
# 21.905288696289062
# Go: 0.2463490894964954
# 21.905288696289062
# Go: 0.2463490894964954
# up
# 28.126487731933594
# Go: 0.3164648359349373
# 22.580337524414062
# Go: 0.2540623940722638
# 21.893577575683594
# Go: 0.2463353228299159
# 21.893577575683594
# Go: 0.2463353228299159
# up
# 24.568099975585938
# Go: 0.28140937579742514
# 21.037254333496094
# Go: 0.24096615596500243
# 23.472518920898438
# Go: 0.268860306840466
# 23.472518920898438
# Go: 0.268860306840466
# up
# 28.26671600341797
# Go: 0.32365559449130965
# 18.782691955566406
# Go: 0.21506295001835044
# 25.631637573242188
# Go: 0.293483788337859
# 25.631637573242188
# Go: 0.293483788337859
# up
# 26.770095825195312
# Go: 0.28469338276183154
# 16.084022521972656
# Go: 0.17104962231357543
# 24.492950439453125
# Go: 0.26047650183840626
# 24.492950439453125
# Go: 0.26047650183840626
# up
# 26.60430908203125
# Go: 0.31373501650512425
# 15.217399597167969
# Go: 0.1794533020595192
# 23.2611083984375
# Go: 0.2743098572794841
# 23.2611083984375
# Go: 0.2743098572794841
# up
# 26.05846405029297
# Go: 0.29991337680737556
# 13.852310180664062
# Go: 0.15942970064728115
# 17.545166015625
# Go: 0.2019317015859552
# 17.545166015625
# Go: 0.2019317015859552
# up
# 22.70587921142578
# Go: 0.26760640317447687
# 20.786514282226562
# Go: 0.2449851983182574
# 22.09503173828125
# Go: 0.260407091769078
# 22.09503173828125
# Go: 0.260407091769078
# up
# 24.458999633789062
# Go: 0.293868088941688
# 21.653099060058594
# Go: 0.26015597267739654
# 23.5791015625
# Go: 0.283296357941047
# 23.5791015625
# Go: 0.283296357941047
# up
# 21.623497009277344
# Go: 0.2568336706034672
# 24.565200805664062
# Go: 0.29177383701272114
# 22.04601287841797
# Go: 0.2618521142674612
# 22.04601287841797
# Go: 0.2618521142674612
# up
# 26.13483428955078
# Go: 0.31185697555737557
# 24.371681213378906
# Go: 0.2908179446728566
# 21.673545837402344
# Go: 0.25862212783032035
# 21.673545837402344
# Go: 0.25862212783032035
# up
# 23.652801513671875
# Go: 0.2674498941760772
# 25.594139099121094
# Go: 0.28940122757260184
# 24.811134338378906
# Go: 0.280547538918477
# 24.811134338378906
# Go: 0.280547538918477
# up
# 24.329910278320312
# Go: 0.29014393546897976
# 18.984947204589844
# Go: 0.22640310768095398
# 32.452354431152344
# Go: 0.38700733879314475
# 32.452354431152344
# Go: 0.38700733879314475
# up
# 24.989280700683594
# Go: 0.2815612212738765
# 19.615402221679688
# Go: 0.22101222806158485
# 29.031410217285156
# Go: 0.3271050261105794
# 29.031410217285156
# Go: 0.3271050261105794
# up
# 26.305885314941406
# Go: 0.3128577516047109
# 19.45117950439453
# Go: 0.23133425136420135
# 24.34173583984375
# Go: 0.2894979832016457
# 24.34173583984375
# Go: 0.2894979832016457
# up
# 26.26140594482422
# Go: 0.3006199278654006
# 23.56525421142578
# Go: 0.26975650260510314
# 23.682708740234375
# Go: 0.2711010297051407
# 23.682708740234375
# Go: 0.2711010297051407
# up
# 25.005264282226562
# Go: 0.30255396946941887
# 23.9105224609375
# Go: 0.2893080193432043
# 19.321823120117188
# Go: 0.23378654256146525
# 19.321823120117188
# Go: 0.23378654256146525
# up
# 27.007179260253906
# Go: 0.308559413290953
# 22.29328155517578
# Go: 0.25470271481177975
# 24.639968872070312
# Go: 0.281513825098441
# 24.639968872070312
# Go: 0.281513825098441
# up
# 24.224891662597656
# Go: 0.2707293051200452
# 22.994842529296875
# Go: 0.2569826864866092
# 27.073974609375
# Go: 0.30256970536428274
# 27.073974609375
# Go: 0.30256970536428274
# up
# 22.171363830566406
# Go: 0.25585058768348534
# 23.486480712890625
# Go: 0.2710266242045787
# 25.298309326171875
# Go: 0.2919345583773372
# 25.298309326171875
# Go: 0.2919345583773372
# up
# 2.67303466796875
# Go: 2.2545688545688547
# 3.7908172607421875
# Go: 3.1973616473616473
# 35.97038269042969
# Go: 30.339189189189188
# 35.97038269042969
# Go: 30.339189189189188
# up
# 17.476730346679688
# Go: 0.22371121485880532
# 18.23009490966797
# Go: 0.2333546720887614
# 33.36254119873047
# Go: 0.42705783486342463
# 33.36254119873047
# Go: 0.42705783486342463
# up
# 20.4742431640625
# Go: 0.24878979077428476
# 19.856185913085938
# Go: 0.2412795578965739
# 27.48504638671875
# Go: 0.33398054742143995
# 27.48504638671875
# Go: 0.33398054742143995
# up
# 25.248680114746094
# Go: 0.31281182039901195
# 23.539657592773438
# Go: 0.2916383394973726
# 28.314552307128906
# Go: 0.3507956301368471
# 28.314552307128906
# Go: 0.3507956301368471
# up
# 19.405517578125
# Go: 0.23367119386690285
# 20.436019897460938
# Go: 0.24607996916869038
# 29.108047485351562
# Go: 0.3505040347238084
# 29.108047485351562
# Go: 0.3505040347238084
# up
# 18.562850952148438
# Go: 0.5884549571610828
# 12.527389526367188
# Go: 0.3971267391028315
# 16.359519958496094
# Go: 0.518607871235345
# 16.359519958496094
# Go: 0.518607871235345
# down
# 0.9725570678710938
# Go: 0.017527206442064746
# 13.884811401367188
# Go: 0.2502289725513085
# 12.262039184570312
# Go: 0.2209837337968298
# 12.262039184570312
# Go: 0.2209837337968298
# up
# 24.649124145507812
# Go: 0.31709126491498035
# 43.7890625
# Go: 0.5633112615117658
# 35.26802062988281
# Go: 0.45369487396635333
# 35.26802062988281
# Go: 0.45369487396635333
# up
# 26.62517547607422
# Go: 0.3416395800155704
# 47.18849182128906
# Go: 0.6054967240264897
# 38.975181579589844
# Go: 0.5001080529158257
# 38.975181579589844
# Go: 0.5001080529158257
# up
# 27.767333984375
# Go: 0.3591707636901028
# 44.30213928222656
# Go: 0.5730486480285253
# 39.910888671875
# Go: 0.516247774161336
# 39.910888671875
# Go: 0.516247774161336
# up
# 28.778076171875
# Go: 0.3741377294516544
# 44.68231201171875
# Go: 0.580905362223372
# 41.05854034423828
# Go: 0.5337934671951907
# 41.05854034423828
# Go: 0.5337934671951907
# up
# 26.489410400390625
# Go: 0.3408193900771772
# 42.098045349121094
# Go: 0.5416439974487773
# 38.493385314941406
# Go: 0.49526553844515303
# 38.493385314941406
# Go: 0.49526553844515303
# up
# 24.180984497070312
# Go: 0.3055167267504019
# 41.69670104980469
# Go: 0.5268205528426602
# 35.72223663330078
# Go: 0.4513356687248042
# 35.72223663330078
# Go: 0.4513356687248042
# up
# 23.51398468017578
# Go: 0.29261245583063505
# 42.379913330078125
# Go: 0.5273836266406432
# 33.6004638671875
# Go: 0.418130503313433
# 33.6004638671875
# Go: 0.418130503313433
# up
# 25.1116943359375
# Go: 0.31160629155127073
# 41.563072204589844
# Go: 0.5157483450495506
# 30.05767822265625
# Go: 0.3729800752711191
# 30.05767822265625
# Go: 0.3729800752711191
# up
# 25.151596069335938
# Go: 0.31424286055399786
# 39.66320037841797
# Go: 0.4955501635475155
# 30.770797729492188
# Go: 0.38444890230377277
# 30.770797729492188
# Go: 0.38444890230377277
# up
# 24.80304718017578
# Go: 0.30191974386388937
# 37.39307403564453
# Go: 0.45517420714938295
# 26.64592742919922
# Go: 0.3243525493460194
# 26.64592742919922
# Go: 0.3243525493460194
# up
# 23.68804931640625
# Go: 0.2827236960219898
# 37.42321014404297
# Go: 0.44665679928331997
# 15.698890686035156
# Go: 0.18737078511260102
# 15.698890686035156
# Go: 0.18737078511260102
# up
# 22.31975555419922
# Go: 0.26305594674760224
# 25.257034301757812
# Go: 0.2976740965711682
# 13.529548645019531
# Go: 0.15945641605442043
# 13.529548645019531
# Go: 0.15945641605442043
# up
# 22.854766845703125
# Go: 0.26951965478034084
# 24.83154296875
# Go: 0.292831203826477
# 13.182868957519531
# Go: 0.15546176053478908
# 13.182868957519531
# Go: 0.15546176053478908
# up
# 15.782966613769531
# Go: 0.19167287735043254
# 24.98912811279297
# Go: 0.30347514539369946
# 13.356742858886719
# Go: 0.16220811957868111
# 13.356742858886719
# Go: 0.16220811957868111
# up
# 14.159736633300781
# Go: 0.16749491566570598
# 24.570274353027344
# Go: 0.29064071862502094
# 14.668121337890625
# Go: 0.17350857647213305
# 14.668121337890625
# Go: 0.17350857647213305
# up
# 13.712577819824219
# Go: 0.16081540672501626
# 20.322341918945312
# Go: 0.23833196968809853
# 13.939132690429688
# Go: 0.1634723479756453
# 13.939132690429688
# Go: 0.1634723479756453
# up
# 13.949508666992188
# Go: 0.1647423327500892
# 22.52094268798828
# Go: 0.2659701300397301
# 13.755035400390625
# Go: 0.16244562249582192
# 13.755035400390625
# Go: 0.16244562249582192
# up
# 11.941032409667969
# Go: 0.13945771665928228
# 19.403953552246094
# Go: 0.22661617218022886
# 13.136672973632812
# Go: 0.15342144251440623
# 13.136672973632812
# Go: 0.15342144251440623
# up
# 16.689453125
# Go: 0.19552932432610595
# 16.737594604492188
# Go: 0.19609333747181332
# 13.812713623046875
# Go: 0.16182618696946396
# 13.812713623046875
# Go: 0.16182618696946396
# up
# 15.543746948242188
# Go: 0.18421609573838937
# 16.466293334960938
# Go: 0.19514961737025724
# 11.552009582519531
# Go: 0.13690817988161266
# 11.552009582519531
# Go: 0.13690817988161266
# up
# 18.363990783691406
# Go: 0.21304098895244922
# 15.197334289550781
# Go: 0.17630454973665882
# 11.537590026855469
# Go: 0.13384779040686917
# 11.537590026855469
# Go: 0.13384779040686917
# up
# 16.959457397460938
# Go: 0.1991670796549378
# 15.708274841308594
# Go: 0.18447354495132337
# 9.673271179199219
# Go: 0.11360016575529255
# 9.673271179199219
# Go: 0.11360016575529255
# up
# 15.612068176269531
# Go: 0.180619148447186
# 16.678237915039062
# Go: 0.1929538800242246
# 9.301300048828125
# Go: 0.10760860606698529
# 9.301300048828125
# Go: 0.10760860606698529
# up
# 17.62104034423828
# Go: 0.20446320027567177
# 16.682891845703125
# Go: 0.1935775294754778
# 7.604408264160156
# Go: 0.08823665456287014
# 7.604408264160156
# Go: 0.08823665456287014
# up
# 15.460700988769531
# Go: 0.17551647904310902
# 19.419822692871094
# Go: 0.22046211909602906
# 10.594711303710938
# Go: 0.12027568645537634
# 10.594711303710938
# Go: 0.12027568645537634
# up
# 14.933319091796875
# Go: 0.17310088604829887
# 19.95708465576172
# Go: 0.23133430790686899
# 9.160308837890625
# Go: 0.10618252824892482
# 9.160308837890625
# Go: 0.10618252824892482
# up
# 13.638153076171875
# Go: 0.15488902102605592
# 20.96759796142578
# Go: 0.2381298041878817
# 9.987716674804688
# Go: 0.1134308765568087
# 9.987716674804688
# Go: 0.1134308765568087
# up
# 14.488296508789062
# Go: 0.1660649140745395
# 21.689453125
# Go: 0.24860460077841973
# 8.804512023925781
# Go: 0.10091735297069022
# 8.804512023925781
# Go: 0.10091735297069022
# up
# 13.090744018554688
# Go: 0.1482018915319837
# 19.58160400390625
# Go: 0.22168570010198527
# 10.878410339355469
# Go: 0.12315579518386824
# 10.878410339355469
# Go: 0.12315579518386824
# up
# 12.910652160644531
# Go: 0.1451712838422553
# 23.13098907470703
# Go: 0.2600918480905587
# 7.4279022216796875
# Go: 0.08352158267132405
# 7.4279022216796875
# Go: 0.08352158267132405
# up
# 12.949256896972656
# Go: 0.14595312774015892
# 21.709632873535156
# Go: 0.24469271443087973
# 7.721405029296875
# Go: 0.0870291804032353
# 7.721405029296875
# Go: 0.0870291804032353
# up
# 13.471908569335938
# Go: 0.1536862095916474
# 20.654029846191406
# Go: 0.23561914360664185
# 9.752006530761719
# Go: 0.1112499325475779
# 9.752006530761719
# Go: 0.1112499325475779
# up
# 13.101272583007812
# Go: 0.1510568563410116
# 20.87627410888672
# Go: 0.24070213935490029
# 10.249252319335938
# Go: 0.11817324045396403
# 10.249252319335938
# Go: 0.11817324045396403
# up
# 13.270530700683594
# Go: 0.15119467957310023
# 20.28614044189453
# Go: 0.231125383985522
# 11.284370422363281
# Go: 0.12856582820048781
# 11.284370422363281
# Go: 0.12856582820048781
# up
# 16.26251220703125
# Go: 0.18564656684362035
# 19.001617431640625
# Go: 0.21691513560462009
# 10.157241821289062
# Go: 0.1159511549456347
# 10.157241821289062
# Go: 0.1159511549456347
# up
# 12.045021057128906
# Go: 0.13762186447415217
# 22.208938598632812
# Go: 0.25375095015934784
# 10.218124389648438
# Go: 0.116748432672929
# 10.218124389648438
# Go: 0.116748432672929
# up
# 13.674697875976562
# Go: 0.15682635678855825
# 21.784019470214844
# Go: 0.2498269753898194
# 8.921585083007812
# Go: 0.1023159486254715
# 8.921585083007812
# Go: 0.1023159486254715
# up
# 13.486099243164062
# Go: 0.15397810712939802
# 21.308746337890625
# Go: 0.24329351039530797
# 9.407997131347656
# Go: 0.10741620419989192
# 9.407997131347656
# Go: 0.10741620419989192
# up
# 11.249885559082031
# Go: 0.1282736176753824
# 22.809371948242188
# Go: 0.26007737068421816
# 10.674667358398438
# Go: 0.12171485588470428
# 10.674667358398438
# Go: 0.12171485588470428
# up
# 11.232337951660156
# Go: 0.1266828586367015
# 21.52454376220703
# Go: 0.2427625260548847
# 10.255851745605469
# Go: 0.11566965154351294
# 10.255851745605469
# Go: 0.11566965154351294
# up
# 13.561973571777344
# Go: 0.1559665819425137
# 19.891624450683594
# Go: 0.22875938066369994
# 9.201583862304688
# Go: 0.10582085091565148
# 9.201583862304688
# Go: 0.10582085091565148
# up
# 13.700447082519531
# Go: 0.15795482782809858
# 21.448593139648438
# Go: 0.24728454598031002
# 9.532432556152344
# Go: 0.10990106630250973
# 9.532432556152344
# Go: 0.10990106630250973
# up
# 13.615531921386719
# Go: 0.15474524391724329
# 20.962371826171875
# Go: 0.23824462827116175
# 5.858726501464844
# Go: 0.06658645925463469
# 5.858726501464844
# Go: 0.06658645925463469
# up
# 13.909530639648438
# Go: 0.15874695136020925
# 21.277008056640625
# Go: 0.24283063537963348
# 5.671272277832031
# Go: 0.06472520229210693
# 5.671272277832031
# Go: 0.06472520229210693
# up
# 13.951225280761719
# Go: 0.15867433479307144
# 19.910049438476562
# Go: 0.2264470529842197
# 6.73492431640625
# Go: 0.07659969746607774
# 6.73492431640625
# Go: 0.07659969746607774
# up
# 14.975090026855469
# Go: 0.17014862752185897
# 20.892715454101562
# Go: 0.23738534148008583
# 7.6740264892578125
# Go: 0.08719313689413513
# 7.6740264892578125
# Go: 0.08719313689413513
# up
# 13.168792724609375
# Go: 0.1495006955362526
# 21.482467651367188
# Go: 0.2438829377056436
# 9.482078552246094
# Go: 0.10764671966026584
# 9.482078552246094
# Go: 0.10764671966026584
# up
# 14.559516906738281
# Go: 0.16687836953105262
# 20.099258422851562
# Go: 0.23037381637548845
# 9.063262939453125
# Go: 0.103881368568429
# 9.063262939453125
# Go: 0.103881368568429
# up
# 15.238189697265625
# Go: 0.1744612124499602
# 20.191688537597656
# Go: 0.23117355366125716
# 8.912811279296875
# Go: 0.10204229590361615
# 8.912811279296875
# Go: 0.10204229590361615
# up
# 14.424934387207031
# Go: 0.16367348926293238
# 20.57910919189453
# Go: 0.2335022480481748
# 8.271751403808594
# Go: 0.09385598424472615
# 8.271751403808594
# Go: 0.09385598424472615
# up
# 13.633918762207031
# Go: 0.15468994168045722
# 21.457481384277344
# Go: 0.2434557959333215
# 7.796287536621094
# Go: 0.08845639213481468
# 7.796287536621094
# Go: 0.08845639213481468
# up
# 13.561439514160156
# Go: 0.15395765206406453
# 19.522857666015625
# Go: 0.2216352714401962
# 7.57049560546875
# Go: 0.08594483846366716
# 7.57049560546875
# Go: 0.08594483846366716
# up
# 14.980010986328125
# Go: 0.17081991095172813
# 19.814529418945312
# Go: 0.22594884302713664
# 8.993377685546875
# Go: 0.10255319417338683
# 8.993377685546875
# Go: 0.10255319417338683
# up
# 14.707107543945312
# Go: 0.16893579188460742
# 20.166091918945312
# Go: 0.23164138137735485
# 8.345413208007812
# Go: 0.0958610647733701
# 8.345413208007812
# Go: 0.0958610647733701
# up
# 14.605598449707031
# Go: 0.1677692659374356
# 20.020980834960938
# Go: 0.22997381925806937
# 8.902740478515625
# Go: 0.1022625837657491
# 8.902740478515625
# Go: 0.1022625837657491
# up
# 13.658485412597656
# Go: 0.15425035110846883
# 20.67302703857422
# Go: 0.23346817621767862
# 11.089057922363281
# Go: 0.12523285169005954
# 11.089057922363281
# Go: 0.12523285169005954
# up
# 12.912521362304688
# Go: 0.14657246025694154
# 22.53559112548828
# Go: 0.2558057363025933
# 8.354988098144531
# Go: 0.09483904239937958
# 8.354988098144531
# Go: 0.09483904239937958
# up
# 12.702789306640625
# Go: 0.14538507095684391
# 21.219635009765625
# Go: 0.24286147452357984
# 7.741203308105469
# Go: 0.0885990757677068
# 7.741203308105469
# Go: 0.0885990757677068
# up
# 14.02435302734375
# Go: 0.16072452819630392
# 20.946083068847656
# Go: 0.24005024062338243
# 8.3111572265625
# Go: 0.0952490871700172
# 8.3111572265625
# Go: 0.0952490871700172
# up
# 13.453025817871094
# Go: 0.15463183994035065
# 22.26024627685547
# Go: 0.2558638395492362
# 8.382492065429688
# Go: 0.09635008427924828
# 8.382492065429688
# Go: 0.09635008427924828
# up
# 13.77197265625
# Go: 0.15739910260137044
# 20.169105529785156
# Go: 0.23051157520413929
# 7.5328826904296875
# Go: 0.08609289352146289
# 7.5328826904296875
# Go: 0.08609289352146289
# up
# 14.088859558105469
# Go: 0.16280010305840587
# 20.909156799316406
# Go: 0.24161025012380893
# 6.819877624511719
# Go: 0.07880529829523852
# 6.819877624511719
# Go: 0.07880529829523852
# up
# 14.279518127441406
# Go: 0.16585752035299703
# 21.004905700683594
# Go: 0.2439733290487542
# 9.162673950195312
# Go: 0.10642504653304384
# 9.162673950195312
# Go: 0.10642504653304384
# up
# 14.926948547363281
# Go: 0.1739732290652592
# 18.752174377441406
# Go: 0.21855614482000535
# 8.788375854492188
# Go: 0.10242831083619143
# 8.788375854492188
# Go: 0.10242831083619143
# up
# 14.85076904296875
# Go: 0.17103294843627057
# 20.457229614257812
# Go: 0.23560128688560242
# 8.384246826171875
# Go: 0.09655947452610565
# 8.384246826171875
# Go: 0.09655947452610565
# up
# 14.132194519042969
# Go: 0.1619735513634699
# 20.544891357421875
# Go: 0.23547149814943488
# 8.280296325683594
# Go: 0.09490309522739909
# 8.280296325683594
# Go: 0.09490309522739909
# up
# 12.483062744140625
# Go: 0.1420153216025178
# 22.3712158203125
# Go: 0.254509287863051
# 7.437896728515625
# Go: 0.08461827979213449
# 7.437896728515625
# Go: 0.08461827979213449
# up
# 14.922752380371094
# Go: 0.17382291915915227
# 20.010986328125
# Go: 0.23309158861229287
# 8.157424926757812
# Go: 0.09501916117403376
# 8.157424926757812
# Go: 0.09501916117403376
# up
# 11.272773742675781
# Go: 0.12876406925204406
# 23.212432861328125
# Go: 0.26514568469951444
# 9.976692199707031
# Go: 0.11395948456288925
# 9.976692199707031
# Go: 0.11395948456288925
# up
# 13.628768920898438
# Go: 0.1585437775993844
# 19.453659057617188
# Go: 0.226304856515374
# 8.946151733398438
# Go: 0.1040707857784097
# 8.946151733398438
# Go: 0.1040707857784097
# up
# 15.745582580566406
# Go: 0.184016625921612
# 20.86559295654297
# Go: 0.24385353759191739
# 7.088470458984375
# Go: 0.08284205491496034
# 7.088470458984375
# Go: 0.08284205491496034
# up
# 13.1005859375
# Go: 0.1539793096355605
# 20.2728271484375
# Go: 0.23827910778723174
# 9.72625732421875
# Go: 0.11431873316704595
# 9.72625732421875
# Go: 0.11431873316704595
# up
# 15.564231872558594
# Go: 0.1825561630216464
# 21.05701446533203
# Go: 0.24698217020653995
# 9.463081359863281
# Go: 0.11099448000798222
# 9.463081359863281
# Go: 0.11099448000798222
# up
# 14.557113647460938
# Go: 0.16595589647880915
# 20.770034790039062
# Go: 0.23678524650923502
# 9.004440307617188
# Go: 0.10265358914754219
# 9.004440307617188
# Go: 0.10265358914754219
# up
# 13.278923034667969
# Go: 0.15215671618549317
# 22.288246154785156
# Go: 0.2553901649698696
# 9.548721313476562
# Go: 0.10941415015629329
# 9.548721313476562
# Go: 0.10941415015629329
# up
# 16.67774200439453
# Go: 0.1941993754328442
# 17.628860473632812
# Go: 0.20527441260754373
# 9.696388244628906
# Go: 0.1129069235250871
# 9.696388244628906
# Go: 0.1129069235250871
# up
# 15.057182312011719
# Go: 0.1740243672250765
# 20.70343017578125
# Go: 0.23928124539308443
# 11.869659423828125
# Go: 0.13718436342243367
# 11.869659423828125
# Go: 0.13718436342243367
# up
# 12.214469909667969
# Go: 0.1408475253892131
# 20.795326232910156
# Go: 0.23979511687596455
# 9.720497131347656
# Go: 0.11208902036915978
# 9.720497131347656
# Go: 0.11208902036915978
# up
# 13.137435913085938
# Go: 0.15242710926694328
# 21.44245147705078
# Go: 0.24878605809128632
# 10.394706726074219
# Go: 0.12060459197786999
# 10.394706726074219
# Go: 0.12060459197786999
# up
# 14.504013061523438
# Go: 0.168892010151804
# 18.20789337158203
# Go: 0.21202185209789068
# 11.272430419921875
# Go: 0.13126183938481506
# 11.272430419921875
# Go: 0.13126183938481506
# up
# 13.882102966308594
# Go: 0.1593693561129592
# 18.883323669433594
# Go: 0.21678438358899976
# 8.609962463378906
# Go: 0.09884411441664433
# 8.609962463378906
# Go: 0.09884411441664433
# up
# 15.771102905273438
# Go: 0.1795313893327271
# 19.826698303222656
# Go: 0.22569852683341377
# 7.839202880859375
# Go: 0.0892380826448865
# 7.839202880859375
# Go: 0.0892380826448865
# up
# 13.963699340820312
# Go: 0.1595294350166238
# 21.823158264160156
# Go: 0.24932047183102082
# 8.219528198242188
# Go: 0.09390467794845495
# 8.219528198242188
# Go: 0.09390467794845495
# up
# 13.297576904296875
# Go: 0.15335379770756555
# 20.953941345214844
# Go: 0.24165052816441537
# 7.702445983886719
# Go: 0.08882816409091276
# 7.702445983886719
# Go: 0.08882816409091276
# up
# 13.257980346679688
# Go: 0.1530797134363621
# 21.310958862304688
# Go: 0.2460612695441733
# 9.881057739257812
# Go: 0.11408898245595489
# 9.881057739257812
# Go: 0.11408898245595489
# up
# 13.13232421875
# Go: 0.15120080665377364
# 20.238113403320312
# Go: 0.2330142799371007
# 8.503150939941406
# Go: 0.09790218850843388
# 8.503150939941406
# Go: 0.09790218850843388
# up
# 14.718208312988281
# Go: 0.16960619855709294
# 18.597145080566406
# Go: 0.21430537019551163
# 8.497085571289062
# Go: 0.09791669963584444
# 8.497085571289062
# Go: 0.09791669963584444
# up
# 13.687248229980469
# Go: 0.15936075021510523
# 19.010848999023438
# Go: 0.2213434802822145
# 9.162063598632812
# Go: 0.10667398618507522
# 9.162063598632812
# Go: 0.10667398618507522
# up
# 12.505455017089844
# Go: 0.1431240236771125
# 21.057281494140625
# Go: 0.2409990560938702
# 7.4062347412109375
# Go: 0.08476381827056488
# 7.4062347412109375
# Go: 0.08476381827056488
# up
# 14.63897705078125
# Go: 0.16634568077834203
# 19.53418731689453
# Go: 0.2219709530528337
# 7.848320007324219
# Go: 0.08918206033494368
# 7.848320007324219
# Go: 0.08918206033494368
# up
# 13.567581176757812
# Go: 0.1572199164117456
# 22.44251251220703
# Go: 0.26006182644281134
# 9.055366516113281
# Go: 0.10493277675610427
# 9.055366516113281
# Go: 0.10493277675610427
# up
# 14.859046936035156
# Go: 0.16977008834106302
# 19.375457763671875
# Go: 0.22137174681169786
# 8.231887817382812
# Go: 0.09405235261634508
# 8.231887817382812
# Go: 0.09405235261634508
# up
# 11.401939392089844
# Go: 0.13052845310769307
# 20.152053833007812
# Go: 0.2306990349019336
# 10.837554931640625
# Go: 0.12406742678163102
# 10.837554931640625
# Go: 0.12406742678163102
# up
# 11.09130859375
# Go: 0.12905271850511152
# 23.169288635253906
# Go: 0.26958583461414226
# 9.368515014648438
# Go: 0.10900718529079882
# 9.368515014648438
# Go: 0.10900718529079882
# up
# 11.789474487304688
# Go: 0.13441380540868847
# 21.557960510253906
# Go: 0.2457859773269613
# 9.161567687988281
# Go: 0.10445259267305282
# 9.161567687988281
# Go: 0.10445259267305282
# up
# 13.903427124023438
# Go: 0.1577906964662365
# 19.997940063476562
# Go: 0.22695763155069287
# 8.097724914550781
# Go: 0.09190148893945534
# 8.097724914550781
# Go: 0.09190148893945534
# up
# 13.912429809570312
# Go: 0.16017996781959648
# 19.916343688964844
# Go: 0.22930568813995994
# 4.562873840332031
# Go: 0.05253438794756707
# 4.562873840332031
# Go: 0.05253438794756707
# up
# 14.35272216796875
# Go: 0.16611484236831797
# 19.33135986328125
# Go: 0.22373635878082757
# 7.80303955078125
# Go: 0.09031044214487301
# 7.80303955078125
# Go: 0.09031044214487301
# up
# 14.677543640136719
# Go: 0.17020981992321021
# 18.690757751464844
# Go: 0.21674951811456802
# 9.360275268554688
# Go: 0.10854750678687343
# 9.360275268554688
# Go: 0.10854750678687343
# up
# 13.621063232421875
# Go: 0.15525929288511947
# 20.042037963867188
# Go: 0.2284485865126892
# 9.853782653808594
# Go: 0.11231805483674843
# 9.853782653808594
# Go: 0.11231805483674843
# up
# 13.462142944335938
# Go: 0.15360548641389155
# 20.968666076660156
# Go: 0.23925627334918564
# 8.009452819824219
# Go: 0.091389305654034
# 8.009452819824219
# Go: 0.091389305654034
# up
# 12.304039001464844
# Go: 0.1423340914647116
# 19.2645263671875
# Go: 0.22285355708358598
# 9.812202453613281
# Go: 0.11350833017812999
# 9.812202453613281
# Go: 0.11350833017812999
# up
# 12.227935791015625
# Go: 0.1399101784580628
# 21.14147186279297
# Go: 0.24189750026024634
# 7.860870361328125
# Go: 0.089942881111397
# 7.860870361328125
# Go: 0.089942881111397
# up
# 14.511604309082031
# Go: 0.17051391222038484
# 19.42279815673828
# Go: 0.22822130685437797
# 7.4236297607421875
# Go: 0.08722896010798846
# 7.4236297607421875
# Go: 0.08722896010798846
# up
# 14.227027893066406
# Go: 0.16600623024671946
# 20.549697875976562
# Go: 0.23978148512398956
# 9.348220825195312
# Go: 0.10907850257753812
# 9.348220825195312
# Go: 0.10907850257753812
# up
# 14.0533447265625
# Go: 0.1623923514260409
# 21.348648071289062
# Go: 0.2466926719239207
# 7.919921875
# Go: 0.0915180522086561
# 7.919921875
# Go: 0.0915180522086561
# up
# 13.851165771484375
# Go: 0.16154228166794296
# 17.685012817382812
# Go: 0.2062553700518361
# 9.077377319335938
# Go: 0.10586691892354826
# 9.077377319335938
# Go: 0.10586691892354826
# up
# 12.479667663574219
# Go: 0.1450734120767905
# 20.032310485839844
# Go: 0.23287123602217163
# 8.62823486328125
# Go: 0.10030134660313798
# 8.62823486328125
# Go: 0.10030134660313798
# up
# 15.401954650878906
# Go: 0.1794181473830808
# 19.020309448242188
# Go: 0.2215685451107196
# 9.76348876953125
# Go: 0.11373537364134813
# 9.76348876953125
# Go: 0.11373537364134813
# up
# 11.96197509765625
# Go: 0.13948404523570038
# 20.994338989257812
# Go: 0.24480700765252647
# 9.208183288574219
# Go: 0.10737312558139017
# 9.208183288574219
# Go: 0.10737312558139017
# up
# 15.199661254882812
# Go: 0.17843916781158042
# 18.48724365234375
# Go: 0.21703433498522234
# 9.426345825195312
# Go: 0.11066228887250193
# 9.426345825195312
# Go: 0.11066228887250193
# up
# 13.7939453125
# Go: 0.15790524026181876
# 18.801918029785156
# Go: 0.2152336635107453
# 8.915863037109375
# Go: 0.10206372891303465
# 8.915863037109375
# Go: 0.10206372891303465
# up
# 13.849716186523438
# Go: 0.15774842369487235
# 20.25341033935547
# Go: 0.2306865723781125
# 5.691795349121094
# Go: 0.06482961327332748
# 5.691795349121094
# Go: 0.06482961327332748
# up
# 12.401275634765625
# Go: 0.14615293836002116
# 20.81195831298828
# Go: 0.24527548214010753
# 9.855537414550781
# Go: 0.11615061181413258
# 9.855537414550781
# Go: 0.11615061181413258
# up
# 11.18560791015625
# Go: 0.13133721142793284
# 20.925140380859375
# Go: 0.245695147589141
# 10.745124816894531
# Go: 0.1261652242087477
# 10.745124816894531
# Go: 0.1261652242087477
# up
# 14.332656860351562
# Go: 0.16680443208985957
# 19.880752563476562
# Go: 0.23137354596434437
# 8.309593200683594
# Go: 0.09670760894109529
# 8.309593200683594
# Go: 0.09670760894109529
# up
# 12.133712768554688
# Go: 0.14055256089255502
# 19.774131774902344
# Go: 0.22905642431161877
# 11.095199584960938
# Go: 0.12852279801131547
# 11.095199584960938
# Go: 0.12852279801131547
# up
# 13.451805114746094
# Go: 0.15696981412219088
# 18.889312744140625
# Go: 0.22042037370087572
# 13.380546569824219
# Go: 0.1561382944521101
# 13.380546569824219
# Go: 0.1561382944521101
# up
# 14.735794067382812
# Go: 0.1723443797987572
# 16.720619201660156
# Go: 0.19555815811377733
# 15.062217712402344
# Go: 0.17616210963369458
# 15.062217712402344
# Go: 0.17616210963369458
# up
# 19.319305419921875
# Go: 0.21689343423312304
# 15.195541381835938
# Go: 0.1705968762178853
# 15.209426879882812
# Go: 0.17075276553646912
# 15.209426879882812
# Go: 0.17075276553646912
# up
# 20.061607360839844
# Go: 0.21815953058011686
# 15.570831298828125
# Go: 0.16932468001169818
# 13.91265869140625
# Go: 0.15129291659666436
# 13.91265869140625
# Go: 0.15129291659666436
# up
# 20.609169006347656
# Go: 0.22130169691962986
# 14.31243896484375
# Go: 0.15368727526097722
# 13.061752319335938
# Go: 0.14025737535184696
# 13.061752319335938
# Go: 0.14025737535184696
# up
# 19.43653106689453
# Go: 0.19593555915624003
# 15.966339111328125
# Go: 0.16095328794471225
# 13.994789123535156
# Go: 0.1410785094704475
# 13.994789123535156
# Go: 0.1410785094704475
# up
# 26.900367736816406
# Go: 0.2436527860468642
# 18.24321746826172
# Go: 0.16523977687179545
# 16.128196716308594
# Go: 0.14608276371115303
# 16.128196716308594
# Go: 0.14608276371115303
# up
# 27.39177703857422
# Go: 0.23619259545247373
# 22.35881805419922
# Go: 0.1927946208102541
# 19.813995361328125
# Go: 0.1708512370002469
# 19.813995361328125
# Go: 0.1708512370002469
# up
# 30.634765625
# Go: 0.25411028259758905
# 22.177810668945312
# Go: 0.1839612486502096
# 18.984107971191406
# Go: 0.15747001627085538
# 18.984107971191406
# Go: 0.15747001627085538
# up
# 33.037872314453125
# Go: 0.26530047648865324
# 22.21271514892578
# Go: 0.17837237994707963
# 17.28130340576172
# Go: 0.13877219405221436
# 17.28130340576172
# Go: 0.13877219405221436
# up
# 35.153541564941406
# Go: 0.27668583139899544
# 20.902252197265625
# Go: 0.16451705204802622
# 17.90966033935547
# Go: 0.1409630165402779
# 17.90966033935547
# Go: 0.1409630165402779
# up
# 31.68354034423828
# Go: 0.24658494151172722
# 22.519454956054688
# Go: 0.17526319416587982
# 17.345619201660156
# Go: 0.13499654552032644
# 17.345619201660156
# Go: 0.13499654552032644
# up
# 29.448623657226562
# Go: 0.2295041576702821
# 27.73395538330078
# Go: 0.2161411053771837
# 16.860580444335938
# Go: 0.13140082055277222
# 16.860580444335938
# Go: 0.13140082055277222
# up
# 35.68859100341797
# Go: 0.2746680653216503
# 26.61144256591797
# Go: 0.2048081260562759
# 17.26398468017578
# Go: 0.13286781961754537
# 17.26398468017578
# Go: 0.13286781961754537
# up
# 34.17564392089844
# Go: 0.26454157950304297
# 27.330169677734375
# Go: 0.2115531830612529
# 17.313575744628906
# Go: 0.1340182699975093
# 17.313575744628906
# Go: 0.1340182699975093
# up
# 34.329071044921875
# Go: 0.2687165983484256
# 27.010498046875
# Go: 0.21142923283170834
# 18.14594268798828
# Go: 0.14204042942382492
# 18.14594268798828
# Go: 0.14204042942382492
# up
# 34.965362548828125
# Go: 0.2718080302186847
# 26.896438598632812
# Go: 0.20908314578986695
# 18.901214599609375
# Go: 0.14693117801613226
# 18.901214599609375
# Go: 0.14693117801613226
# up
# 34.99908447265625
# Go: 0.2679505794904403
# 27.48943328857422
# Go: 0.2104572073961521
# 17.589874267578125
# Go: 0.13466686555312155
# 17.589874267578125
# Go: 0.13466686555312155
# up
# 34.929351806640625
# Go: 0.2735959971676833
# 27.182884216308594
# Go: 0.21291916191930915
# 17.211685180664062
# Go: 0.1348163629261725
# 17.211685180664062
# Go: 0.1348163629261725
# up
# 34.044837951660156
# Go: 0.2627886956531021
# 27.80792236328125
# Go: 0.21464656865294496
# 17.68512725830078
# Go: 0.1365097267100182
# 17.68512725830078
# Go: 0.1365097267100182
# up
# 34.66876983642578
# Go: 0.2682689521543358
# 26.577072143554688
# Go: 0.20565492600174298
# 18.407745361328125
# Go: 0.1424402014523987
# 18.407745361328125
# Go: 0.1424402014523987
# up
# 36.12781524658203
# Go: 0.2789487667062527
# 24.111785888671875
# Go: 0.1861710399819035
# 19.182510375976562
# Go: 0.14811129804520348
# 19.182510375976562
# Go: 0.14811129804520348
# up
# 36.548118591308594
# Go: 0.2810581170566764
# 23.761634826660156
# Go: 0.1827289775774565
# 18.52008819580078
# Go: 0.14242104153818702
# 18.52008819580078
# Go: 0.14242104153818702
# up
# 35.732574462890625
# Go: 0.27820229599579005
# 22.503585815429688
# Go: 0.1752056585929067
# 18.88427734375
# Go: 0.14702689056755777
# 18.88427734375
# Go: 0.14702689056755777
# up
# 35.63343048095703
# Go: 0.2774182811347029
# 23.83434295654297
# Go: 0.18555840304269178
# 18.228378295898438
# Go: 0.14191407637341386
# 18.228378295898438
# Go: 0.14191407637341386
# up
# 36.118736267089844
# Go: 0.283081127159972
# 21.72271728515625
# Go: 0.17025211648012342
# 18.20575714111328
# Go: 0.14268788958164458
# 18.20575714111328
# Go: 0.14268788958164458
# up
# 35.63129425048828
# Go: 0.28092306411776535
# 21.50604248046875
# Go: 0.1695572242812178
# 18.171615600585938
# Go: 0.14326804686351896
# 18.171615600585938
# Go: 0.14326804686351896
# up
# 33.437843322753906
# Go: 0.2580194605261454
# 24.23816680908203
# Go: 0.18703116298072903
# 17.872772216796875
# Go: 0.13791329186432735
# 17.872772216796875
# Go: 0.13791329186432735
# up
# 34.53723907470703
# Go: 0.26691705258800846
# 20.441970825195312
# Go: 0.15798340423068333
# 18.810272216796875
# Go: 0.14537301049528423
# 18.810272216796875
# Go: 0.14537301049528423
# up
# 31.308212280273438
# Go: 0.24278489742075102
# 22.667312622070312
# Go: 0.1757775602288516
# 18.809356689453125
# Go: 0.14586037981084338
# 18.809356689453125
# Go: 0.14586037981084338
# up
# 32.45250701904297
# Go: 0.25823572729927396
# 23.331451416015625
# Go: 0.18565635997943156
# 17.057762145996094
# Go: 0.13573446301959163
# 17.057762145996094
# Go: 0.13573446301959163
# up
# 33.217315673828125
# Go: 0.2636070554390305
# 21.931724548339844
# Go: 0.17404649387255847
# 17.256240844726562
# Go: 0.1369426380413136
# 17.256240844726562
# Go: 0.1369426380413136
# up
# 30.359268188476562
# Go: 0.24191167214699116
# 24.57530975341797
# Go: 0.1958233722588926
# 16.746673583984375
# Go: 0.13344247247498614
# 16.746673583984375
# Go: 0.13344247247498614
# up
# 31.77288055419922
# Go: 0.2582559467319417
# 24.09942626953125
# Go: 0.1958846676277155
# 16.04602813720703
# Go: 0.1304251334968775
# 16.04602813720703
# Go: 0.1304251334968775
# up
# 30.671005249023438
# Go: 0.24681652993128772
# 24.537086486816406
# Go: 0.1974554955773008
# 16.115188598632812
# Go: 0.12968257469257372
# 16.115188598632812
# Go: 0.12968257469257372
# up
# 27.593040466308594
# Go: 0.22475197071809644
# 23.742637634277344
# Go: 0.19338951083933792
# 16.807289123535156
# Go: 0.1368994242427067
# 16.807289123535156
# Go: 0.1368994242427067
# up
# 25.987319946289062
# Go: 0.21277201464669476
# 23.21605682373047
# Go: 0.1900822090445175
# 15.233116149902344
# Go: 0.12472162651865369
# 15.233116149902344
# Go: 0.12472162651865369
# up
# 26.799468994140625
# Go: 0.22012217477539064
# 23.449974060058594
# Go: 0.19261050618783424
# 14.951057434082031
# Go: 0.12280315249162056
# 14.951057434082031
# Go: 0.12280315249162056
# up
# 26.46038055419922
# Go: 0.21794846416500216
# 21.848983764648438
# Go: 0.17996538051738184
# 16.446533203125
# Go: 0.13546655707077324
# 16.446533203125
# Go: 0.13546655707077324
# up
# 26.38782501220703
# Go: 0.217357191246652
# 21.10363006591797
# Go: 0.17383114197984734
# 15.960693359375
# Go: 0.13146864045589202
# 15.960693359375
# Go: 0.13146864045589202
# up
# 26.594085693359375
# Go: 0.2194911813659119
# 22.658119201660156
# Go: 0.18700614145737965
# 15.604972839355469
# Go: 0.12879382142279747
# 15.604972839355469
# Go: 0.12879382142279747
# up
# 27.937164306640625
# Go: 0.22760559615838094
# 22.90691375732422
# Go: 0.18662387150885953
# 14.98626708984375
# Go: 0.12209393257431754
# 14.98626708984375
# Go: 0.12209393257431754
# up
# 30.35259246826172
# Go: 0.24993344688590322
# 20.85651397705078
# Go: 0.1717395452714307
# 15.969314575195312
# Go: 0.13149670297050695
# 15.969314575195312
# Go: 0.13149670297050695
# up
# 26.680679321289062
# Go: 0.22252686046272083
# 23.114089965820312
# Go: 0.19278016914819568
# 15.596160888671875
# Go: 0.13007782433254597
# 15.596160888671875
# Go: 0.13007782433254597
# up
# 27.561912536621094
# Go: 0.22989985340491223
# 21.356048583984375
# Go: 0.17813540450949034
# 15.298004150390625
# Go: 0.1276039500847246
# 15.298004150390625
# Go: 0.1276039500847246
# up
# 26.747703552246094
# Go: 0.22154338176765978
# 21.81285858154297
# Go: 0.18066950857053846
# 14.285736083984375
# Go: 0.11832456109378464
# 14.285736083984375
# Go: 0.11832456109378464
# up
# 27.228775024414062
# Go: 0.22629694701581693
# 23.289451599121094
# Go: 0.19355743289326147
# 15.22491455078125
# Go: 0.12653348078748633
# 15.22491455078125
# Go: 0.12653348078748633
# up
# 26.802520751953125
# Go: 0.22152391568520022
# 20.4693603515625
# Go: 0.1691800893883864
# 14.691848754882812
# Go: 0.12142872287858254
# 14.691848754882812
# Go: 0.12142872287858254
# up
# 25.59295654296875
# Go: 0.21136450783714145
# 22.628517150878906
# Go: 0.18688209713675497
# 14.767723083496094
# Go: 0.12196217018451083
# 14.767723083496094
# Go: 0.12196217018451083
# up
# 26.917800903320312
# Go: 0.22346442313622558
# 22.834320068359375
# Go: 0.18956445142420433
# 15.451583862304688
# Go: 0.128274939202222
# 15.451583862304688
# Go: 0.128274939202222
# up
# 28.18157196044922
# Go: 0.23399342866160805
# 21.56658172607422
# Go: 0.17906873362767683
# 13.253974914550781
# Go: 0.11004861751513328
# 13.253974914550781
# Go: 0.11004861751513328
# up
# 25.59825897216797
# Go: 0.21233430590294658
# 23.21666717529297
# Go: 0.19257930453025845
# 13.501548767089844
# Go: 0.11199363164470741
# 13.501548767089844
# Go: 0.11199363164470741
# up
# 24.59606170654297
# Go: 0.20294786534363762
# 23.46790313720703
# Go: 0.19363916478224025
# 14.391403198242188
# Go: 0.11874683814140434
# 14.391403198242188
# Go: 0.11874683814140434
# up
# 27.605438232421875
# Go: 0.23240127227220006
# 19.798049926757812
# Go: 0.16667339068297019
# 14.562721252441406
# Go: 0.1225988487600934
# 14.562721252441406
# Go: 0.1225988487600934
# up
# 28.42548370361328
# Go: 0.23565273102117373
# 21.030006408691406
# Go: 0.17434280082174874
# 12.785987854003906
# Go: 0.10599830025817908
# ...
# Go: 0.8758422067334302
# 7.928810119628906
# Go: 0.12192892069947706
# 4.048118591308594
# Go: 0.062251803644510224
# 4.048118591308594
# Go: 0.062251803644510224
# up
# 55.06324768066406
# Go: 0.8389518463610038
# 5.404205322265625
# Go: 0.08233927754357317
# 1.9219207763671875
# Go: 0.029282671324507323
# 1.9219207763671875
# Go: 0.029282671324507323
# up
# 58.54637145996094
# Go: 0.8840144269711266
# 7.499504089355469
# Go: 0.11323792824040574
# 5.325469970703125
# Go: 0.08041134176389839
# 5.325469970703125
# Go: 0.08041134176389839
# up
# 56.212005615234375
# Go: 0.8740917640819944
# 3.299102783203125
# Go: 0.051300759332385426
# 3.625030517578125
# Go: 0.05636890705607884
# 3.625030517578125
# Go: 0.05636890705607884
# up
# 55.54534912109375
# Go: 0.8357597456482206
# 6.13555908203125
# Go: 0.0923183196963781
# 2.8176116943359375
# Go: 0.042395024430576224
# 2.8176116943359375
# Go: 0.042395024430576224
# up
# 56.18366241455078
# Go: 0.8625131581451664
# 6.6632843017578125
# Go: 0.10229255516172624
# 3.9908599853515625
# Go: 0.06126637356395041
# 3.9908599853515625
# Go: 0.06126637356395041
# up
# 57.952880859375
# Go: 0.8798720154568354
# 8.124618530273438
# Go: 0.12335235755399403
# 6.229743957519531
# Go: 0.09458334582164318
# 6.229743957519531
# Go: 0.09458334582164318
# up
# 57.95478820800781
# Go: 0.8808843458429927
# 7.462882995605469
# Go: 0.11343215994668018
# 5.3861236572265625
# Go: 0.0818664369438575
# 5.3861236572265625
# Go: 0.0818664369438575
# up
# 56.638641357421875
# Go: 0.8615846883471784
# 5.4730224609375
# Go: 0.08325539310815464
# 2.7415084838867188
# Go: 0.04170371456802546
# 2.7415084838867188
# Go: 0.04170371456802546
# up
# 57.60490417480469
# Go: 0.8865897457688442
# 7.55584716796875
# Go: 0.11629108173480211
# 2.0866775512695312
# Go: 0.032115788511124295
# 2.0866775512695312
# Go: 0.032115788511124295
# up
# 57.497825622558594
# Go: 0.8746834956386124
# 6.3454437255859375
# Go: 0.09652982246159984
# 4.080238342285156
# Go: 0.06207047132002249
# 4.080238342285156
# Go: 0.06207047132002249
# up
# 57.28118896484375
# Go: 0.9013385843668604
# 4.142913818359375
# Go: 0.06519012862120903
# 3.2426834106445312
# Go: 0.05102470335757314
# 3.2426834106445312
# Go: 0.05102470335757314
# up
# 58.310089111328125
# Go: 0.887921519969701
# 6.314048767089844
# Go: 0.0961476798248977
# 3.5730743408203125
# Go: 0.05440927372977645
# 3.5730743408203125
# Go: 0.05440927372977645
# up
# 57.318572998046875
# Go: 0.8720480918006451
# 6.966667175292969
# Go: 0.10599127819583781
# 5.0777435302734375
# Go: 0.0772530843777096
# 5.0777435302734375
# Go: 0.0772530843777096
# up
# 57.013206481933594
# Go: 0.8658054475519644
# 5.7151031494140625
# Go: 0.08678984651831614
# 3.7114334106445312
# Go: 0.056362016161653025
# 3.7114334106445312
# Go: 0.056362016161653025
# up
# 56.989593505859375
# Go: 0.8593356856597105
# 6.256523132324219
# Go: 0.09434097113201717
# 4.591522216796875
# Go: 0.06923472602041396
# 4.591522216796875
# Go: 0.06923472602041396
# up
# 56.221656799316406
# Go: 0.8383519106230926
# 4.178733825683594
# Go: 0.06231138828320302
# 1.7154312133789062
# Go: 0.025579734165645972
# 1.7154312133789062
# Go: 0.025579734165645972
# up
# 56.85020446777344
# Go: 0.8656804503438513
# 4.23858642578125
# Go: 0.0645426246087054
# 4.668235778808594
# Go: 0.07108506449789692
# 4.668235778808594
# Go: 0.07108506449789692
# up
# 57.15564727783203
# Go: 0.8620426334829666
# 8.876075744628906
# Go: 0.1338722606481943
# 6.272010803222656
# Go: 0.09459678907600604
# 6.272010803222656
# Go: 0.09459678907600604
# up
# 57.388572692871094
# Go: 0.885688360602535
# 7.062187194824219
# Go: 0.10899202934226436
# 4.238128662109375
# Go: 0.06540781641067984
# 4.238128662109375
# Go: 0.06540781641067984
# up
# 57.183189392089844
# Go: 0.8573706578402884
# 7.139091491699219
# Go: 0.10703928258794992
# 3.6869430541992188
# Go: 0.055279826560981196
# 3.6869430541992188
# Go: 0.055279826560981196
# up
# 55.08289337158203
# Go: 0.836060438676028
# 2.8277587890625
# Go: 0.04292035346990862
# 2.824859619140625
# Go: 0.04287634922234072
# 2.824859619140625
# Go: 0.04287634922234072
# up
# 56.89544677734375
# Go: 0.8438311522989969
# 6.355133056640625
# Go: 0.0942546293938931
# 3.6433029174804688
# Go: 0.05403477208049742
# 3.6433029174804688
# Go: 0.05403477208049742
# up
# 58.41255187988281
# Go: 0.8601384057485613
# 8.689994812011719
# Go: 0.12796219379248294
# 4.986991882324219
# Go: 0.07343461480614867
# 4.986991882324219
# Go: 0.07343461480614867
# up
# 57.29084014892578
# Go: 0.8769134831480356
# 8.824195861816406
# Go: 0.13506620445870696
# 2.6202011108398438
# Go: 0.040105707590989165
# 2.6202011108398438
# Go: 0.040105707590989165
# up
# 57.029571533203125
# Go: 0.8596192077969683
# 6.88385009765625
# Go: 0.10376177846777497
# 4.578666687011719
# Go: 0.06901524462556871
# 4.578666687011719
# Go: 0.06901524462556871
# up
# 56.673622131347656
# Go: 0.858364622896666
# 5.565910339355469
# Go: 0.0842998973745655
# 3.6566162109375
# Go: 0.05538220210638524
# 3.6566162109375
# Go: 0.05538220210638524
# up
# 58.57128143310547
# Go: 0.8505462604470432
# 6.733360290527344
# Go: 0.09777888199170648
# 6.273918151855469
# Go: 0.09110706632748096
# 6.273918151855469
# Go: 0.09110706632748096
# up
# 57.24822998046875
# Go: 0.862966451489735
# 7.805824279785156
# Go: 0.11766589957413139
# 4.765357971191406
# Go: 0.07183355817080057
# 4.765357971191406
# Go: 0.07183355817080057
# up
# 57.230377197265625
# Go: 0.8682448332832009
# 4.113121032714844
# Go: 0.06240035904382878
# 4.65576171875
# Go: 0.07063278725857391
# 4.65576171875
# Go: 0.07063278725857391
# up
# 56.1346435546875
# Go: 0.8557831336336789
# 5.7773590087890625
# Go: 0.08807691798829295
# 2.977752685546875
# Go: 0.045396396290301406
# 2.977752685546875
# Go: 0.045396396290301406
# up
# 55.85468292236328
# Go: 0.8413133870058128
# 6.081199645996094
# Go: 0.09159831196862966
# 4.6572113037109375
# Go: 0.07014943082521796
# 4.6572113037109375
# Go: 0.07014943082521796
# up
# 57.44331359863281
# Go: 0.8555572884397026
# 8.184318542480469
# Go: 0.12189675248988464
# 6.171722412109375
# Go: 0.091921265698581
# 6.171722412109375
# Go: 0.091921265698581
# up
# 57.288360595703125
# Go: 0.8747303927136283
# 4.567298889160156
# Go: 0.06973764145827618
# 3.883819580078125
# Go: 0.059301662522446646
# 3.883819580078125
# Go: 0.059301662522446646
# up
# 57.57072448730469
# Go: 0.8515313514342328
# 7.056427001953125
# Go: 0.10437195075763187
# 5.659523010253906
# Go: 0.08371027671290421
# 5.659523010253906
# Go: 0.08371027671290421
# up
# 57.33631134033203
# Go: 0.870320765817097
# 4.972076416015625
# Go: 0.07547226622937454
# 5.0327301025390625
# Go: 0.07639294217923419
# 5.0327301025390625
# Go: 0.07639294217923419
# up
# 56.36009216308594
# Go: 0.8567888208023751
# 5.5014801025390625
# Go: 0.08363376404855198
# 4.641265869140625
# Go: 0.07055674606678239
# 4.641265869140625
# Go: 0.07055674606678239
# up
# 55.697784423828125
# Go: 0.8453071291620116
# 4.334869384765625
# Go: 0.06578890045329881
# 2.788848876953125
# Go: 0.042325450863632735
# 2.788848876953125
# Go: 0.042325450863632735
# up
# 57.40386962890625
# Go: 0.865641110601056
# 7.541770935058594
# Go: 0.11372869129427844
# 5.038337707519531
# Go: 0.07597732133591506
# 5.038337707519531
# Go: 0.07597732133591506
# up
# 58.54728698730469
# Go: 0.8853914324913564
# 7.6593017578125
# Go: 0.1158291101806931
# 5.0620269775390625
# Go: 0.07655137492408565
# 5.0620269775390625
# Go: 0.07655137492408565
# up
# 57.86964416503906
# Go: 0.8745632100066831
# 6.2237548828125
# Go: 0.09405737890981541
# 3.885345458984375
# Go: 0.058717834637163624
# 3.885345458984375
# Go: 0.058717834637163624
# up
# 58.108062744140625
# Go: 0.8761317106754805
# 4.890289306640625
# Go: 0.07373395934382782
# 5.565605163574219
# Go: 0.08391612011533225
# 5.565605163574219
# Go: 0.08391612011533225
# up
# 58.414344787597656
# Go: 0.8773024543805984
# 6.151123046875
# Go: 0.09238133827987825
# 3.9835357666015625
# Go: 0.05982718316639317
# 3.9835357666015625
# Go: 0.05982718316639317
# up
# 57.859039306640625
# Go: 0.862806467550043
# 6.0054779052734375
# Go: 0.08955498120073531
# 4.615936279296875
# Go: 0.06883383691300117
# 4.615936279296875
# Go: 0.06883383691300117
# up
# 57.92724609375
# Go: 0.8380459788193786
# 5.026054382324219
# Go: 0.07271301414221353
# 4.766693115234375
# Go: 0.06896077868129812
# 4.766693115234375
# Go: 0.06896077868129812
# up
# 58.55804443359375
# Go: 0.8540752294848972
# 2.0508575439453125
# Go: 0.029911972717467837
# 4.63836669921875
# Go: 0.06765106556047672
# 4.63836669921875
# Go: 0.06765106556047672
# up
# 59.084205627441406
# Go: 0.8720754412087215
# 4.277763366699219
# Go: 0.06313924907315835
# 4.6971893310546875
# Go: 0.06932992353573939
# 4.6971893310546875
# Go: 0.06932992353573939
# up
# 61.13147735595703
# Go: 0.8905547513828044
# 4.3387603759765625
# Go: 0.0632064500165535
# 3.4626388549804688
# Go: 0.05044323510570414
# 3.4626388549804688
# Go: 0.05044323510570414
# up
# 60.33985137939453
# Go: 0.8508578316175894
# 2.896270751953125
# Go: 0.0408405820605952
# 3.5378265380859375
# Go: 0.04988721960728782
# 3.5378265380859375
# Go: 0.04988721960728782
# up
# 61.248779296875
# Go: 0.9081730483697174
# 9.72808837890625
# Go: 0.14424430624255846
# 5.999565124511719
# Go: 0.08895921536020635
# 5.999565124511719
# Go: 0.08895921536020635
# up
# 60.16246795654297
# Go: 0.8617522751053884
# 1.9507980346679688
# Go: 0.027942747392951887
# 3.3111190795898438
# Go: 0.04742764878000803
# 3.3111190795898438
# Go: 0.04742764878000803
# up
# 60.71403503417969
# Go: 0.8726883722664438
# 3.3031082153320312
# Go: 0.04747805231912594
# 5.113983154296875
# Go: 0.07350711630694458
# 5.113983154296875
# Go: 0.07350711630694458
# up
# 62.15110778808594
# Go: 0.8967597701097231
# 4.097938537597656
# Go: 0.059127931129238906
# 3.2579803466796875
# Go: 0.04700842528297676
# 3.2579803466796875
# Go: 0.04700842528297676
# up
# 61.80347442626953
# Go: 0.8925411948351153
# 4.5623016357421875
# Go: 0.06588694553121618
# 3.505859375
# Go: 0.050630226609984216
# 3.505859375
# Go: 0.050630226609984216
# up
# 62.13600158691406
# Go: 0.8660499045613811
# 4.932823181152344
# Go: 0.06875355568670612
# 5.0092315673828125
# Go: 0.06981853370126383
# 5.0092315673828125
# Go: 0.06981853370126383
# up
# 61.87065124511719
# Go: 0.8784379865602241
# 5.577735900878906
# Go: 0.07919255730671539
# 2.1936798095703125
# Go: 0.03114581204976148
# 2.1936798095703125
# Go: 0.03114581204976148
# up
# 61.49982452392578
# Go: 0.8537833728203529
# 2.6182174682617188
# Go: 0.036347917382430955
# 2.853546142578125
# Go: 0.0396149138468036
# 2.853546142578125
# Go: 0.0396149138468036
# up
# 60.50701141357422
# Go: 0.8515158628318377
# 4.44610595703125
# Go: 0.06257009992388911
# 5.602912902832031
# Go: 0.07884985728705694
# 5.602912902832031
# Go: 0.07884985728705694
# up
# 59.458045959472656
# Go: 0.8118583974573709
# 0.6893539428710938
# Go: 0.009412650185674044
# 3.1779861450195312
# Go: 0.043393197627044376
# 3.1779861450195312
# Go: 0.043393197627044376
# up
# 62.89329528808594
# Go: 0.8144785315170083
# 2.8336334228515625
# Go: 0.0366960194807737
# 7.4895477294921875
# Go: 0.09699087650760917
# 7.4895477294921875
# Go: 0.09699087650760917
# up
# 63.79730224609375
# Go: 0.854559674764033
# 2.4642562866210938
# Go: 0.03300851253407169
# 3.37615966796875
# Go: 0.04522338415943716
# 3.37615966796875
# Go: 0.04522338415943716
# up
# 63.14643859863281
# Go: 0.852708302586875
# 4.732704162597656
# Go: 0.06390884779402049
# 1.3660049438476562
# Go: 0.018446072064289526
# 1.3660049438476562
# Go: 0.018446072064289526
# up
# 63.036231994628906
# Go: 0.8662106165326037
# 3.2411956787109375
# Go: 0.044538799644595416
# 4.710044860839844
# Go: 0.06472294954355672
# 4.710044860839844
# Go: 0.06472294954355672
# up
# 62.98053741455078
# Go: 0.8687605491486979
# 3.460693359375
# Go: 0.04773718972158634
# 6.729011535644531
# Go: 0.09282073473675777
# 6.729011535644531
# Go: 0.09282073473675777
# up
# 63.40099334716797
# Go: 0.8320652868408401
# 4.026374816894531
# Go: 0.05284154932089455
# 5.1677703857421875
# Go: 0.0678210564429941
# 5.1677703857421875
# Go: 0.0678210564429941
# up
# 64.61322784423828
# Go: 0.8554912681703197
# 2.2340774536132812
# Go: 0.029579604946988792
# 2.5580978393554688
# Go: 0.03386969569094376
# 2.5580978393554688
# Go: 0.03386969569094376
# up
# 65.32020568847656
# Go: 0.858610645096226
# 1.8771743774414062
# Go: 0.02467478303512768
# 7.080421447753906
# Go: 0.09306959711367867
# 7.080421447753906
# Go: 0.09306959711367867
# up
# 66.00631713867188
# Go: 0.8406171286240894
# 2.8806304931640625
# Go: 0.036685993686077854
# 6.3433837890625
# Go: 0.08078555655998244
# 6.3433837890625
# Go: 0.08078555655998244
# up
# 65.85403442382812
# Go: 0.8505591586267329
# 3.3147048950195312
# Go: 0.042812147065413385
# 7.0461273193359375
# Go: 0.09100654465207217
# 7.0461273193359375
# Go: 0.09100654465207217
# up
# 67.59662628173828
# Go: 0.8742045630438711
# 7.144813537597656
# Go: 0.0924014842195298
# 6.204833984375
# Go: 0.08024504299167547
# 6.204833984375
# Go: 0.08024504299167547
# up
# 66.84078216552734
# Go: 0.8703308094876827
# 5.041046142578125
# Go: 0.06563923442831192
# 7.621612548828125
# Go: 0.09924067319852747
# 7.621612548828125
# Go: 0.09924067319852747
# up
# 66.5814208984375
# Go: 0.8652683204204309
# 6.060981750488281
# Go: 0.07876634996035284
# 6.308174133300781
# Go: 0.08197877371176478
# 6.308174133300781
# Go: 0.08197877371176478
# up
# 68.28720092773438
# Go: 0.8656116271223281
# 5.6914520263671875
# Go: 0.07214510160470604
# 5.588264465332031
# Go: 0.07083709144477943
# 5.588264465332031
# Go: 0.07083709144477943
# up
# 69.51335906982422
# Go: 0.8707594848700098
# 5.958061218261719
# Go: 0.07463368749057743
# 7.727241516113281
# Go: 0.09679533448064702
# 7.727241516113281
# Go: 0.09679533448064702
# up
# 68.94317626953125
# Go: 0.8884702097613154
# 5.8562469482421875
# Go: 0.07546941171055761
# 7.513923645019531
# Go: 0.09683187921197296
# 7.513923645019531
# Go: 0.09683187921197296
# up
# 67.90874481201172
# Go: 0.8408184886009624
# 6.076774597167969
# Go: 0.07524015421730679
# 8.783836364746094
# Go: 0.10875789321050171
# 8.783836364746094
# Go: 0.10875789321050171
# up
# 69.560546875
# Go: 0.8656986776703935
# 10.182151794433594
# Go: 0.12671946585066848
# 6.703834533691406
# Go: 0.08343092387652781
# 6.703834533691406
# Go: 0.08343092387652781
# up
# 68.15475463867188
# Go: 0.8470199428619142
# 4.806098937988281
# Go: 0.059729679454141586
# 4.7772216796875
# Go: 0.05937079600124661
# 4.7772216796875
# Go: 0.05937079600124661
# up
# 69.48173522949219
# Go: 0.8639861433741218
# 7.771720886230469
# Go: 0.09663919782222528
# 7.025146484375
# Go: 0.08735575180478675
# 7.025146484375
# Go: 0.08735575180478675
# up
# 69.3265151977539
# Go: 0.8604793316742613
# 7.812767028808594
# Go: 0.09697190941012034
# 6.593284606933594
# Go: 0.08183571777593436
# 6.593284606933594
# Go: 0.08183571777593436
# up
# 71.47171020507812
# Go: 0.8565664351565717
# 10.051651000976562
# Go: 0.12046594156820302
# 7.8443145751953125
# Go: 0.09401169431432443
# 7.8443145751953125
# Go: 0.09401169431432443
# up
# 71.94599151611328
# Go: 0.8368513087969132
# 9.728622436523438
# Go: 0.11316002806038573
# 9.748573303222656
# Go: 0.11339208975773735
# 9.748573303222656
# Go: 0.11339208975773735
# up
# 71.58756256103516
# Go: 0.8657659655767346
# 10.450477600097656
# Go: 0.12638603001006762
# 2.0893478393554688
# Go: 0.025268163698449787
# 2.0893478393554688
# Go: 0.025268163698449787
# up
# 73.01868438720703
# Go: 0.8563527161695131
# 13.816566467285156
# Go: 0.16203872093413416
# 9.9713134765625
# Go: 0.11694214228992607
# 9.9713134765625
# Go: 0.11694214228992607
# up
# 73.75492095947266
# Go: 0.8582077469872205
# 14.36309814453125
# Go: 0.16712813108630067
# 8.265151977539062
# Go: 0.0961728026398184
# 8.265151977539062
# Go: 0.0961728026398184
# up
# 74.46475982666016
# Go: 0.8614809200226398
# 10.944747924804688
# Go: 0.12661951147932024
# 1.7626190185546875
# Go: 0.020391694773320798
# 1.7626190185546875
# Go: 0.020391694773320798
# up
# 74.84809875488281
# Go: 0.8427395355135016
# 16.26300811767578
# Go: 0.18311059512715142
# 4.0572357177734375
# Go: 0.04568176080814771
# 4.0572357177734375
# Go: 0.04568176080814771
# up
# 75.94497680664062
# Go: 0.8683638531832579
# 17.44464874267578
# Go: 0.19946417836411598
# 7.254638671875
# Go: 0.08295039718822858
# 7.254638671875
# Go: 0.08295039718822858
# up
# 75.53760528564453
# Go: 0.8642241374607341
# 13.406600952148438
# Go: 0.15338463670296745
# 6.585731506347656
# Go: 0.07534721426630835
# 6.585731506347656
# Go: 0.07534721426630835
# up
# 75.70392608642578
# Go: 0.8495606021056296
# 12.310752868652344
# Go: 0.13815308082603145
# 8.876686096191406
# Go: 0.09961547801330271
# 8.876686096191406
# Go: 0.09961547801330271
# up
# 76.77116394042969
# Go: 0.8757218686354102
# 14.695777893066406
# Go: 0.1676334370487471
# 6.548919677734375
# Go: 0.0747029468275202
# 6.548919677734375
# Go: 0.0747029468275202
# up
# 75.26416778564453
# Go: 0.8582944453634218
# 17.92621612548828
# Go: 0.20442625195445832
# 7.850799560546875
# Go: 0.08952862766874572
# 7.850799560546875
# Go: 0.08952862766874572
# up
# 76.23672485351562
# Go: 0.8624878837391363
# 16.17633819580078
# Go: 0.1830075429388201
# 6.797752380371094
# Go: 0.0769049178856294
# 6.797752380371094
# Go: 0.0769049178856294
# up
# 76.88323974609375
# Go: 0.8707973250645419
# 19.20421600341797
# Go: 0.21751138454838187
# 7.462654113769531
# Go: 0.08452374355728913
# 7.462654113769531
# Go: 0.08452374355728913

# %%
cv2.putText??

# %% [markdown]
# Extração de características imagem. Criação da variável **states**

# %%
# Dimensões da imagem
image_height, image_width, _ = img.shape

# Mostrando resultados
if results.multi_hand_landmarks:  # Caso haja algum resultado
        
    # Mostrando resultados
    for num, hand in enumerate(results.multi_hand_landmarks):  # Iteração em cada mão identificada

        # print('hand_landmarks:', hand_landmarks)
        print(
          f'Index finger tip coordinates: (',
          f'{hand.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].x * image_width}, '
          f'{hand.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].y * image_height})'
        )

        # --- Testar funções de extrações ---
        hand_fingers_points = extrair_pontos_dedos(hand, image_height, image_width)
        # 1. Direção da mão
        print("\n---Extração de informações---")
        hand_direction = verificar_direcao_mao(hand)  # up ou down
        print(f"Direção da mão: {hand_direction}")
        # finger = "middle-finger"
        # finger = "thumb"
        # estado = verificar_condicao_dedos(finger, hand, hand_direction, image_height)
        # print(estado)
        states = dict()
        # 2. Condição dos dedos (esticado ou dobrado)
        print("Verificar estado dos dedos (esticado ou dobrado)")
        for f in HAND_FINGERS:
            estado = verificar_condicao_dedos(f, hand, hand_direction, image_height)
            states.update({f: estado})
        print(f"Estado dos dedos:\n{states}")
        # 3. Condição dos dedos (proximidade entre os dedos)
        print("Verificar proximidade entre os dedos (próximo ou afastado)")
        estados = verificar_distancia_dedos_adjacentes(states, hand, hand_fingers_points)
        print(f"Estado dos dedos:\n{estados}")
        print("\n---Identificação---")
        letter = encontrar_letra(AlphabetLetters, estados)
        print(f"Letra indentificada: {letter}\n")
    
plt.imshow(annotated_image)
plt.title("Letra A - depois de processar a imagem")
plt.show()
# Out:
# Index finger tip coordinates: ( 463.5917282104492, 140.9516716003418)
#
# ---Extração de informações---
# Direção da mão: up
# Verificar estado dos dedos (esticado ou dobrado)
# Estado dos dedos:
# {'thumb': ['esticado'], 'index-finger': ['esticado-vertical'], 'middle-finger': ['esticado-vertical'], 'ring-finger': ['esticado-vertical'], 'pinky': ['esticado-vertical']}
# Verificar proximidade entre os dedos (próximo ou afastado)
# 23.32996368408203
# 25.830001831054688
# 27.118492126464844
# 27.118492126464844
# Estado dos dedos:
# {'thumb': ['esticado', 'afastado do index-finger'], 'index-finger': ['esticado-vertical', 'proximo do middle-finger'], 'middle-finger': ['esticado-vertical', 'proximo do ring-finger'], 'ring-finger': ['esticado-vertical', 'proximo do pinky'], 'pinky': ['esticado-vertical', 'proximo do ring-finger']}
#
# ---Identificação---
# Letra indentificada: A

# %%
results.multi_hand_landmarks[0].landmark[8].y*image_height
# Out:
# 140.9516716003418

# %%
def str2float(lista):
    for i, value in enumerate(lista):
        lista[i] = float(lista[i])
    return lista

# %%
def verificar_direcao_mao(hand):
    """
    Verifica se mão está voltada para cima (up) ou para baixo (down).
    """
    # Ponta dos dedos (valor da vertical)
    pos_thumb = hand.landmark[4].y  # Polegar
    pos_index_finger = hand.landmark[8].y  # Indicador
    pos_middle_finger = hand.landmark[12].y  # Médio
    pos_ring_finger = hand.landmark[16].y  # Anelar
    pos_pinky = hand.landmark[20].y  # Mínimo
    
    # Lista dos dedos
    fingers = [pos_thumb, pos_index_finger, pos_middle_finger, pos_ring_finger, pos_pinky]
    
    # Posicao do pulso (referência)
    pos_wrist = hand.landmark[0].y  # Pulso
    
    # Ponto (0,0) é o campo superior esquerda da imagem
    # Se todas as pontas do dedos tiverem valor superior ao valor do pulso, mão está para 'baixo',
    # caso contrário, está para 'cima'
    
    aux = 0  # Variável auxiliar
    for elem  in fingers:
        # print(elem, pos_wrist)
        if elem < pos_wrist:
            aux += 1
    # print(aux)
    
    if aux == 5:  # Todos as pontas dos dedos estão acima do pulso
        return "up"
    else:
        return "down"

# %%
def verificar_condicao_dedos(finger, hand, hand_direction, img_height):
    """
    Verifica se o dedo está dobrado ou esticado.
    Para verificar se o dedo está esticado ou dobrado é verificado a posição y da ponta e da base do dedo.
    """
    # Caracteristica do dedo
    positions = []
    
    # Determinar conjuntos de pontos para cada dedo
    points = []
    len_finger = 4  # Número de pontos de um dedo
    
    if finger == "thumb":
        init = 1
    elif finger == "index-finger":
        init = 5
    elif finger == "middle-finger":
        init = 9
    elif finger == "ring-finger":
        init = 13
    elif finger == "pinky":
        init = 17
    else:
        raise Exception("Dedo não encontrado")
        
    # Pontos do dedo. 0 para base do dedo, 3 para ponta do dedo
    for i in range(init, init+len_finger):
        points.append(hand.landmark[i].y * img_height)
    # print(f"Pontos do dedo: {points}")
    
    if hand_direction == "up":  # Mão voltada para cima
        if finger == "thumb":  # Polegar
            if points[3] <= points[2]:
                # print(points[2] - points[3])
                # aux = (points[2] - points[3])/(points[2] - points[1])
                # print(f"Teste:{aux}")
                if points[2] - points[3] < 20:  # TODO: adicionar, melhorar lógica
                    positions.append("dobrado")
                else:
                    positions.append("esticado")
            else:  # Polegar dobrado
                positions.append("dobrado")
        else:  # Outros dedos
            if points[3] < points[1]:  # Ponta do dedo com valor menor que base do dedo
            # if points[2] < points[1]:
                positions.append("esticado-vertical")
            else:
                positions.append("dobrado")
    else:  # Mão voltada para baixo
        if finger == "thumb":  # Polegar
            if points[2] <= points[3]:
                if points[3] - points[2] < 20:  # TODO: adicionar, melhorar lógica -> como normalizar ? Pois valor muda se mao está próxima ou longe da tela
                    positions.append("dobrado")
                else:
                    positions.append("esticado")
            else:  # Polegar dobrado
                positions.append("dobrado")
        else:  # Outros
            if points[3] > points[1]:  # Ponta do dedo com valor maior que base do dedo
            # if points[2] > points[1]:
                positions.append("esticado-vertical")
            else:
                positions.append("dobrado")
    return positions

# %%
states
# Out:
# {'thumb': ['esticado'],
#  'index-finger': ['esticado-vertical'],
#  'middle-finger': ['esticado-vertical'],
#  'ring-finger': ['esticado-vertical'],
#  'pinky': ['esticado-vertical']}

# %%
hand.landmark[1].y*image_height
# Out:
# 331.51147842407227

# %%
img_height = image_height
img_width = image_width
HAND_FINGERS
# Out:
# ['thumb', 'index-finger', 'middle-finger', 'ring-finger', 'pinky']

# %%
def extrair_pontos_dedos(hand, img_height, img_width):
    """
    Cria um dicionário com os valores do pontos dos dedos da mão
    """
    hand_fingers_points = dict()
    
    for finger in HAND_FINGERS:
        if finger == "thumb":
            init = 1
        elif finger == "index-finger":
            init = 5
        elif finger == "middle-finger":
            init = 9
        elif finger == "ring-finger":
            init = 13
        elif finger == "pinky":
            init = 17
        else:
            raise Exception("Dedo não encontrado")
            
        # Pontos do dedo. 0 -> para base do dedo, 3 -> para ponta do dedo
        points_x = []
        points_y = []
        len_finger = 4  # Número de pontos de um dedo
        
        for i in range(init, init+len_finger):
            points_x.append(hand.landmark[i].x * img_width)
            points_y.append(hand.landmark[i].y * img_height)
            
        # Atualiza dicionário
        points = {'x': points_x, 'y': points_y}
        hand_fingers_points.update({finger: points})
    
    return hand_fingers_points

# %%
states
# Out:
# {'thumb': ['esticado'],
#  'index-finger': ['esticado-vertical'],
#  'middle-finger': ['esticado-vertical'],
#  'ring-finger': ['esticado-vertical'],
#  'pinky': ['esticado-vertical']}

# %%
hand_fingers_points = extrair_pontos_dedos(hand, img_height, img_width)
for f in hand_fingers_points.keys():
    print(f)
    print(f"x:{hand_fingers_points[f]['x']}")
    print(f"y:{hand_fingers_points[f]['y']}")
    print("\n")
# Out:
# thumb
# x:[479.4277572631836, 449.4084167480469, 441.24507904052734, 432.3826599121094]
# y:[331.51147842407227, 296.9026851654053, 260.36736488342285, 229.05632972717285]
#
#
# index-finger
# x:[469.08042907714844, 462.5526428222656, 462.34683990478516, 463.5917282104492]
# y:[239.3615484237671, 194.09016609191895, 165.3944492340088, 140.9516716003418]
#
#
# middle-finger
# x:[495.7095718383789, 488.5313034057617, 487.3316955566406, 486.92169189453125]
# y:[232.57062435150146, 182.81888008117676, 149.6715545654297, 120.15329360961914]
#
#
# ring-finger
# x:[521.778564453125, 516.9036483764648, 515.2219390869141, 512.7516937255859]
# y:[235.8427333831787, 189.06786918640137, 158.1302547454834, 130.34146785736084]
#
#
# pinky
# x:[550.1354217529297, 546.4920043945312, 543.9999389648438, 539.8701858520508]
# y:[246.40256881713867, 209.0320587158203, 185.30327796936035, 162.07839488983154]

# %%
states_copy = states.copy()
states_copy['thumb']
# Out:
# ['esticado']

# %%
from copy import deepcopy
def verificar_distancia_dedos_adjacentes(states, hand, hand_fingers_points):
    """
    Verifica se dedo está próximo ou afastado do dedo adjacente (mais próximo) da mesma mão.
    Para verificar tal condição é utilizado o ponto x das pontas dos dedos.
    """
    # states_copy = states.copy()
    states_copy = deepcopy(states)  # Constroi uma cópia
    for i, finger_name in enumerate(HAND_FINGERS):
        if i == len(HAND_FINGERS)-1:  # Caso para o último dedo (mínimo)
            adjacent_finger = HAND_FINGERS[len(HAND_FINGERS)-2]  # Anelar
        else:
            adjacent_finger = HAND_FINGERS[i+1]
        # print(f"Index: {i}, finger: {finger_name}, adjacent: {adjacent_finger}")
        # print(states[finger_name], states[adjacent_finger])
        if states[finger_name] == states[adjacent_finger]:  # TODO: verificar lógica para dedão !!!!
            if finger_name not in ['pinky']:
                aux = hand_fingers_points[adjacent_finger]['x'][3] - hand_fingers_points[finger_name]['x'][3]
                aux = abs(aux)
            else:
                aux = hand_fingers_points[finger_name]['x'][3] - hand_fingers_points[adjacent_finger]['x'][3]
                aux = abs(aux)
            print(aux)
            refer_dist = abs(hand_fingers_points['index-finger']['y'][0] - hand_fingers_points['index-finger']['y'][3])
            if aux < 50:  # TODO: normalizar distâncias!!! (fazer isso antes) (testar valores)
                states_copy[finger_name].append(f"proximo do {adjacent_finger}")
            else:
                states_copy[finger_name].append(f"afastado do {adjacent_finger}")
            aux = aux / refer_dist
            print(f"Go: {aux}")
        else:  # Estados diferentes
            states_copy[finger_name].append(f"afastado do {adjacent_finger}")
        # print(f"Estado atualizado do {finger_name}: {states_copy[finger_name]}")
        # print("\n")
    return states_copy

# %%
refer_dist = abs(hand_fingers_points['index-finger']['y'][0] - hand_fingers_points['index-finger']['y'][3])
refer_dist
# Out:
# 112.89894104003906

# %%
verificar_distancia_dedos_adjacentes(states, hand, hand_fingers_points)
# Out:
# 50.12603759765625
# 5.4299163818359375
# 11.519432067871094
# 11.519432067871094
# {'thumb': ['esticado', 'afastado do index-finger'],
#  'index-finger': ['esticado-vertical', 'afastado do middle-finger'],
#  'middle-finger': ['esticado-vertical', 'proximo do ring-finger'],
#  'ring-finger': ['esticado-vertical', 'proximo do pinky'],
#  'pinky': ['esticado-vertical', 'proximo do ring-finger']}

# %%
print(hand_fingers_points['index-finger']['x'][3])
print(hand_fingers_points['pinky']['x'][3])
# Out:
# 463.5917282104492
# 539.8701858520508

# %%
HAND_FINGERS
# Out:
# ['thumb', 'index-finger', 'middle-finger', 'ring-finger', 'pinky']

# %%
LETTERS.remove('')

# %%
hand_direction
# Out:
# 'up'

# %%
estados
# Out:
# {'thumb': ['esticado', 'afastado do index-finger'],
#  'index-finger': ['esticado-vertical', 'proximo do middle-finger'],
#  'middle-finger': ['esticado-vertical', 'proximo do ring-finger'],
#  'ring-finger': ['esticado-vertical', 'proximo do pinky'],
#  'pinky': ['esticado-vertical', 'proximo do ring-finger']}

# %%
class Alphabet:
    def __init__(self):
        A = {
            'thumb': ['esticado', 'afastado do index-finger'],
             'index-finger': ['esticado-vertical', 'proximo do middle-finger'],
             'middle-finger': ['esticado-vertical', 'proximo do ring-finger'],
             'ring-finger': ['esticado-vertical', 'proximo do pinky'],
             'pinky': ['esticado-vertical', 'proximo do ring-finger']
        }
        B = {
            'thumb': ['esticado-vertical', 'afastado do index-finger'],
             'index-finger': ['esticado-vertical', 'proximo do middle-finger'],
             'middle-finger': ['esticado-vertical', 'proximo do ring-finger'],
             'ring-finger': ['esticado-vertical', 'proximo do pinky'],
             'pinky': ['esticado-vertical', 'proximo do ring-finger']
        }

# %%
alphabet = Alphabet()
alphabet

# %%
from enum import Enum
class AlphabetLetters(Enum):
    A = {
        'thumb': ['esticado', 'afastado do index-finger'],
         'index-finger': ['esticado-vertical', 'proximo do middle-finger'],
         'middle-finger': ['esticado-vertical', 'proximo do ring-finger'],
         'ring-finger': ['esticado-vertical', 'proximo do pinky'],
         'pinky': ['esticado-vertical', 'proximo do ring-finger']
    }
    B = {
        'thumb': ['esticado-vertical', 'afastado do index-finger'],
         'index-finger': ['esticado-vertical', 'proximo do middle-finger'],
         'middle-finger': ['esticado-vertical', 'proximo do ring-finger'],
         'ring-finger': ['esticado-vertical', 'proximo do pinky'],
         'pinky': ['esticado-vertical', 'proximo do ring-finger']
    }

# %%
for l in AlphabetLetters:
    print(l.name, l.value)
# Out:
# A {'thumb': ['esticado', 'afastado do index-finger'], 'index-finger': ['esticado-vertical', 'proximo do middle-finger'], 'middle-finger': ['esticado-vertical', 'proximo do ring-finger'], 'ring-finger': ['esticado-vertical', 'proximo do pinky'], 'pinky': ['esticado-vertical', 'proximo do ring-finger']}
# B {'thumb': ['esticado-vertical', 'afastado do index-finger'], 'index-finger': ['esticado-vertical', 'proximo do middle-finger'], 'middle-finger': ['esticado-vertical', 'proximo do ring-finger'], 'ring-finger': ['esticado-vertical', 'proximo do pinky'], 'pinky': ['esticado-vertical', 'proximo do ring-finger']}

# %%
def encontrar_letra(AlphabetLetters, estados):
    for l in AlphabetLetters:
        if l.value == estados:
            return l.name
    return "Not found"

# %%
encontrar_letra(AlphabetLetters, estados)
# Out:
# 'A'

# %% [markdown]
# **Observação**: execute o bloco anterior do teste feito com uma imagem (para gerar o 'results')

# %%
def extrair_condicao_dedos(hand):

# %%
results.multi_handedness
# Out:
# [classification {
#    index: 1
#    score: 0.9999918937683105
#    label: "Right"
#  }]

# %%
for i, hand in enumerate(results.multi_hand_landmarks):
        hand_direction = verificar_direcao_mao(hand)  # Verificar se mão está para cima ou para baixo
        print(f"Direção mão: {hand_direction}")

        # Extrair os valores isolados dos dedos
        h = img.shape[0]
        print(f"Altura: {h}px")

        # Posições dos dedos
        positions_fingers = dict()

        # 2. Indicador
        pos_index_finger = verificar_condicao_dedos("index-finger", hand, hand_direction, h)
        positions_fingers.update({'index': pos_index_finger})

        # 3. Médio
        pos_middle_finger = verificar_condicao_dedos("middle-finger", hand, hand_direction, h)
        positions_fingers.update({'middle-finger': pos_middle_finger})

        # 4. Anelar
        pos_ring_finger = verificar_condicao_dedos("ring-finger", hand, hand_direction, h)
        positions_fingers.update({'ring-finger': pos_ring_finger})

        # 5. Mínimo
        pos_pinky_finger = verificar_condicao_dedos("pinky", hand, hand_direction, h)
        positions_fingers.update({'pinky': pos_pinky_finger})
# Out:
# Direção mão: up
# Altura: 480px

# %%
positions_fingers
# Out:
# {'index': ['esticado-vertical'],
#  'middle-finger': ['esticado-vertical'],
#  'ring-finger': ['esticado-vertical'],
#  'pinky': ['esticado-vertical']}

# %%
"""
# Polegar (pontos 1 a 4)
thumb_points_x = [hand.landmark[1].x, hand.landmark[2].x, hand.landmark[3].x, hand.landmark[4].x]
thumb_points_y = [hand.landmark[1].y, hand.landmark[2].y, hand.landmark[3].y, hand.landmark[4].y]
thumb_points_z = [hand.landmark[1].z, hand.landmark[2].z, hand.landmark[3].z, hand.landmark[4].z]
thumb_point = {'x': thumb_points_x,
               'y': thumb_points_y,
               'z': thumb_points_z
              } 
# thumb_point['y']

# Indicador (pontos 5 a 8)
index_finger_points_x = [hand.landmark[5].x, hand.landmark[6].x, hand.landmark[7].x, hand.landmark[8].x]
index_finger_y = [hand.landmark[5].y, hand.landmark[6].y, hand.landmark[7].y, hand.landmark[8].y]
index_finger_z = [hand.landmark[5].z, hand.landmark[6].z, hand.landmark[7].z, hand.landmark[8].z]
index_finger = {'x': thumb_points_x,
               'y': thumb_points_y,
               'z': thumb_points_z
               }
"""
# Out:
# "\n# Polegar (pontos 1 a 4)\nthumb_points_x = [hand.landmark[1].x, hand.landmark[2].x, hand.landmark[3].x, hand.landmark[4].x]\nthumb_points_y = [hand.landmark[1].y, hand.landmark[2].y, hand.landmark[3].y, hand.landmark[4].y]\nthumb_points_z = [hand.landmark[1].z, hand.landmark[2].z, hand.landmark[3].z, hand.landmark[4].z]\nthumb_point = {'x': thumb_points_x,\n               'y': thumb_points_y,\n               'z': thumb_points_z\n              } \n# thumb_point['y']\n\n# Indicador (pontos 5 a 8)\nindex_finger_points_x = [hand.landmark[5].x, hand.landmark[6].x, hand.landmark[7].x, hand.landmark[8].x]\nindex_finger_y = [hand.landmark[5].y, hand.landmark[6].y, hand.landmark[7].y, hand.landmark[8].y]\nindex_finger_z = [hand.landmark[5].z, hand.landmark[6].z, hand.landmark[7].z, hand.landmark[8].z]\nindex_finger = {'x': thumb_points_x,\n               'y': thumb_points_y,\n               'z': thumb_points_z\n               }\n"

# %%
# results.multi_hand_landmarks[0]

# %% [markdown]
# ## Alfabeto
#
# Abaixo segue as caracteristicas de cada um dos cinco dedos da mão para as letras do alfabeto manual de letras. Para isso, foram explorados duas características principais:
# - Dedo esticado ou dobrado
# - Proximidade de um dedo do outro
#
# **Observação**: letras H, J, K, X, Y, Z não foram consideradas pois envolvem movimento.

# %%
LETTERS = ['A', 'B', 'C', 'D', 'E', 'F', 'G', '', 'I', '', '', 'L', 'M', 'N', 'O', 'P', 'Q', 'R',
           'S', 'T', 'U', 'V', 'W', '', '', '']  # 20 letras

A = {
    'thumb': "",
    'index_finger': "",
    'middle-finger': "",
    'ring-finger': "",
    'pinky': ""
}

# %% [markdown]
# **Resultados**

# %% [markdown]
# Usa as linhas abaixo para explorar os resultados da detecção.
#
# Observação: se não houver uma mão na image (ou frame) processado, os resultados abaixo serão vazios.

# %%
results.multi_handedness
# Out:
# [classification {
#    index: 1
#    score: 1.0
#    label: "Right"
#  },
#  classification {
#    index: 0
#    score: 0.9999999403953552
#    label: "Left"
#  }]

# %%
print(results.multi_hand_landmarks)
# Out:
# [landmark {
#   x: 0.18796910345554352
#   y: 0.7147940993309021
#   z: -4.518930654739961e-05
# }
# landmark {
#   x: 0.26594090461730957
#   y: 0.6942442059516907
#   z: -0.03975929692387581
# }
# landmark {
#   x: 0.3330771327018738
#   y: 0.6286066770553589
#   z: -0.06637011468410492
# }
# landmark {
#   x: 0.38321971893310547
#   y: 0.5680602788925171
#   z: -0.09083607792854309
# }
# landmark {
#   x: 0.4186285138130188
#   y: 0.5337807536125183
#   z: -0.12230817973613739
# }
# landmark {
#   x: 0.27292537689208984
#   y: 0.47934240102767944
#   z: -0.04457118734717369
# }
# landmark {
#   x: 0.3129063844680786
#   y: 0.3997867703437805
#   z: -0.07958994060754776
# }
# landmark {
#   x: 0.33730173110961914
#   y: 0.3488754630088806
#   z: -0.10341078042984009
# }
# landmark {
#   x: 0.3554779887199402
#   y: 0.3001047372817993
#   z: -0.12120037525892258
# }
# landmark {
#   x: 0.22484438121318817
#   y: 0.4537581205368042
#   z: -0.05227091535925865
# }
# landmark {
#   x: 0.24213789403438568
#   y: 0.34331321716308594
#   z: -0.08176230639219284
# }
# landmark {
#   x: 0.25357040762901306
#   y: 0.2720390856266022
#   z: -0.107645183801651
# }
# landmark {
#   x: 0.2616753578186035
#   y: 0.21155408024787903
#   z: -0.1268472522497177
# }
# landmark {
#   x: 0.17676116526126862
#   y: 0.4619145691394806
#   z: -0.0677192285656929
# }
# landmark {
#   x: 0.16880273818969727
#   y: 0.35589373111724854
#   z: -0.10057280957698822
# }
# landmark {
#   x: 0.16616404056549072
#   y: 0.28508421778678894
#   z: -0.13599610328674316
# }
# landmark {
#   x: 0.1647241711616516
#   y: 0.2236683964729309
#   z: -0.16186749935150146
# }
# landmark {
#   x: 0.12999580800533295
#   y: 0.49787768721580505
#   z: -0.08429285138845444
# }
# landmark {
#   x: 0.09137886762619019
#   y: 0.4292829632759094
#   z: -0.11640620231628418
# }
# landmark {
#   x: 0.06657831370830536
#   y: 0.38192400336265564
#   z: -0.14331072568893433
# }
# landmark {
#   x: 0.04509781301021576
#   y: 0.3332310914993286
#   z: -0.16466906666755676
# }
# ]

# %%
results.multi_hand_landmarks[1].landmark[0]
# Out:
# x: 0.2734813690185547
# y: 0.7162407636642456
# z: 5.669892925652675e-05

# %% [markdown]
# Hand

# %%
hand.landmark[mp_hands.HandLandmark.WRIST]
# Out:
# x: 0.2734813690185547
# y: 0.7162407636642456
# z: 5.669892925652675e-05

# %%
# print(hand.landmark)

# %%
'''
def get_label(index_hand, mark_name, results):
    """
    Retorna o label (left ou right) e o score para um índice específico, e
    as coordenadas x e y desta mão de uma coordenadas específica.
    """
    output = None
    
    # Loop sobre as mãos detectadas
    for i, c in enumerate(results.multi_handedness):
        
        # Mão desejada tem index passado por parâmetro
        if c.classification[0].index == index_hand:  # 0, 1, 2, etc.
            
            # Extrair informações (label e score)
            label = c.classification[0].label
            score = c.classification[0].score
            text = 'Label: {}, Score: {}'.format(label, round(score, 2))
            # print(text)
            
            # Extrair coordenadas
            x = results.multi_hand_landmarks[i].landmark[mark_name].x
            y = results.multi_hand_landmarks[i].landmark[mark_name].y
            # print(x, y)
            multiply = np.multiply(np.array((x, y)),[640,480])
            coords = tuple(multiply.astype(int))
            # print(coords)
            
            text = text + str(coords)
            
            output = text, coords
    
    return output
    
r = get_label(0, mp_hands.HandLandmark.WRIST, results)
print(r)
'''
# Out:
# '\ndef get_label(index_hand, mark_name, results):\n    """\n    Retorna o label (left ou right) e o score para um índice específico, e\n    as coordenadas x e y desta mão de uma coordenadas específica.\n    """\n    output = None\n    \n    # Loop sobre as mãos detectadas\n    for i, c in enumerate(results.multi_handedness):\n        \n        # Mão desejada tem index passado por parâmetro\n        if c.classification[0].index == index_hand:  # 0, 1, 2, etc.\n            \n            # Extrair informações (label e score)\n            label = c.classification[0].label\n            score = c.classification[0].score\n            text = \'Label: {}, Score: {}\'.format(label, round(score, 2))\n            # print(text)\n            \n            # Extrair coordenadas\n            x = results.multi_hand_landmarks[i].landmark[mark_name].x\n            y = results.multi_hand_landmarks[i].landmark[mark_name].y\n            # print(x, y)\n            multiply = np.multiply(np.array((x, y)),[640,480])\n            coords = tuple(multiply.astype(int))\n            # print(coords)\n            \n            text = text + str(coords)\n            \n            output = text, coords\n    \n    return output\n    \nr = get_label(0, mp_hands.HandLandmark.WRIST, results)\nprint(r)\n'

# %% [markdown]
# ## 3. Mais detalhes

# %% [markdown]
# Conexões ("traços") entre os pontos da mão. Sugere-se olhar juntamente com a imagem apresentada no começo.

# %%
mp_hands.HAND_CONNECTIONS
# Out:
# frozenset({(<HandLandmark.WRIST: 0>, <HandLandmark.THUMB_CMC: 1>),
#            (<HandLandmark.WRIST: 0>, <HandLandmark.INDEX_FINGER_MCP: 5>),
#            (<HandLandmark.WRIST: 0>, <HandLandmark.PINKY_MCP: 17>),
#            (<HandLandmark.THUMB_CMC: 1>, <HandLandmark.THUMB_MCP: 2>),
#            (<HandLandmark.THUMB_MCP: 2>, <HandLandmark.THUMB_IP: 3>),
#            (<HandLandmark.THUMB_IP: 3>, <HandLandmark.THUMB_TIP: 4>),
#            (<HandLandmark.INDEX_FINGER_MCP: 5>,
#             <HandLandmark.INDEX_FINGER_PIP: 6>),
#            (<HandLandmark.INDEX_FINGER_MCP: 5>,
#             <HandLandmark.MIDDLE_FINGER_MCP: 9>),
#            (<HandLandmark.INDEX_FINGER_PIP: 6>,
#             <HandLandmark.INDEX_FINGER_DIP: 7>),
#            (<HandLandmark.INDEX_FINGER_DIP: 7>,
#             <HandLandmark.INDEX_FINGER_TIP: 8>),
#            (<HandLandmark.MIDDLE_FINGER_MCP: 9>,
#             <HandLandmark.MIDDLE_FINGER_PIP: 10>),
#            (<HandLandmark.MIDDLE_FINGER_MCP: 9>,
#             <HandLandmark.RING_FINGER_MCP: 13>),
#            (<HandLandmark.MIDDLE_FINGER_PIP: 10>,
#             <HandLandmark.MIDDLE_FINGER_DIP: 11>),
#            (<HandLandmark.MIDDLE_FINGER_DIP: 11>,
#             <HandLandmark.MIDDLE_FINGER_TIP: 12>),
#            (<HandLandmark.RING_FINGER_MCP: 13>,
#             <HandLandmark.RING_FINGER_PIP: 14>),
#            (<HandLandmark.RING_FINGER_MCP: 13>, <HandLandmark.PINKY_MCP: 17>),
#            (<HandLandmark.RING_FINGER_PIP: 14>,
#             <HandLandmark.RING_FINGER_DIP: 15>),
#            (<HandLandmark.RING_FINGER_DIP: 15>,
#             <HandLandmark.RING_FINGER_TIP: 16>),
#            (<HandLandmark.PINKY_MCP: 17>, <HandLandmark.PINKY_PIP: 18>),
#            (<HandLandmark.PINKY_PIP: 18>, <HandLandmark.PINKY_DIP: 19>),
#            (<HandLandmark.PINKY_DIP: 19>, <HandLandmark.PINKY_TIP: 20>)})

# %% [markdown]
# Extrações do objeto instanciado

# %%
hand.landmark[mp_hands.HandLandmark.WRIST]
# Out:
# x: 0.2734813690185547
# y: 0.7162407636642456
# z: 5.669892925652675e-05

# %%
hand.landmark[0].x
# Out:
# 0.2734813690185547

# %% [markdown]
# Enum

# %%
for mark in mp_hands.HandLandmark:
    print(mark)
# Out:
# HandLandmark.WRIST
# HandLandmark.THUMB_CMC
# HandLandmark.THUMB_MCP
# HandLandmark.THUMB_IP
# HandLandmark.THUMB_TIP
# HandLandmark.INDEX_FINGER_MCP
# HandLandmark.INDEX_FINGER_PIP
# HandLandmark.INDEX_FINGER_DIP
# HandLandmark.INDEX_FINGER_TIP
# HandLandmark.MIDDLE_FINGER_MCP
# HandLandmark.MIDDLE_FINGER_PIP
# HandLandmark.MIDDLE_FINGER_DIP
# HandLandmark.MIDDLE_FINGER_TIP
# HandLandmark.RING_FINGER_MCP
# HandLandmark.RING_FINGER_PIP
# HandLandmark.RING_FINGER_DIP
# HandLandmark.RING_FINGER_TIP
# HandLandmark.PINKY_MCP
# HandLandmark.PINKY_PIP
# HandLandmark.PINKY_DIP
# HandLandmark.PINKY_TIP
